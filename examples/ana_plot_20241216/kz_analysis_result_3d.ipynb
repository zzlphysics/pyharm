# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pyharm.ana_results as an
from matplotlib.colors import Normalize

# %%
plt.rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 10,        # 默认字体大小
    "axes.labelsize": 10,   # 轴标签字体大小
    "legend.fontsize": 10,  # 图例字体大小
    "mathtext.fontset": "stix",  # 数学字体设置为 STIX，这个与 Times New Roman 很接近
})

# %%
ana_file_a05e00 = "/home/zhangzelin/projects/kharma-data-sync/20241216_cuda_sane_a05000_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"
ana_file_a05ef5 = "/home/zhangzelin/projects/kharma-data-sync/20241217_cuda_kz_sane_a05000_eta-05_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"
ana_file_a05ez5 = "/home/zhangzelin/projects/kharma-data-sync/20241217_cuda_kz_sane_a05000_eta+05_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"
ana_file_a09e00 = "/home/zhangzelin/projects/kharma-data-sync/20241217_cuda_sane_a09375_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"
ana_file_a09ef1 = "/home/zhangzelin/projects/kharma-data-sync/20241217_cuda_kz_sane_a09375_eta-01_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"
ana_file_a09ez5 = "/home/zhangzelin/projects/kharma-data-sync/20241217_cuda_kz_sane_a09375_eta+05_288-192-128_6-12_rout1000_min020_gamma13/eht_out.h5"

# %%
ana_a05e00 = an.load_results(ana_file_a05e00)
ana_a05ef5 = an.load_results(ana_file_a05ef5)
ana_a05ez5 = an.load_results(ana_file_a05ez5)
ana_a09e00 = an.load_results(ana_file_a09e00)
ana_a09ef1 = an.load_results(ana_file_a09ef1)
ana_a09ez5 = an.load_results(ana_file_a09ez5)

# %%
# r, th = ana.get_ivar('rth')
mdot_a05e00 = ana_a05e00.get_result('t', 'mdot')
phi_b_a05e00 = ana_a05e00.get_result('t', 'phi_b')
edot_a05e00 = ana_a05e00.get_result('t', 'edot')
ldot_a05e00 = ana_a05e00.get_result('t', 'ldot')
eff_a05e00 = ana_a05e00.get_result('t', 'eff')

mdot_a05ef5 = ana_a05ef5.get_result('t', 'mdot')
phi_b_a05ef5 = ana_a05ef5.get_result('t', 'phi_b')
edot_a05ef5 = ana_a05ef5.get_result('t', 'edot')
ldot_a05ef5 = ana_a05ef5.get_result('t', 'ldot')
eff_a05ef5 = ana_a05ef5.get_result('t', 'eff')

mdot_a05ez5 = ana_a05ez5.get_result('t', 'mdot')
phi_b_a05ez5 = ana_a05ez5.get_result('t', 'phi_b')
edot_a05ez5 = ana_a05ez5.get_result('t', 'edot')
ldot_a05ez5 = ana_a05ez5.get_result('t', 'ldot')
eff_a05ez5 = ana_a05ez5.get_result('t', 'eff')

mdot_a09e00 = ana_a09e00.get_result('t', 'mdot')
phi_b_a09e00 = ana_a09e00.get_result('t', 'phi_b')
edot_a09e00 = ana_a09e00.get_result('t', 'edot')
ldot_a09e00 = ana_a09e00.get_result('t', 'ldot')
eff_a09e00 = ana_a09e00.get_result('t', 'eff')

mdot_a09ef1 = ana_a09ef1.get_result('t', 'mdot')
phi_b_a09ef1 = ana_a09ef1.get_result('t', 'phi_b')
edot_a09ef1 = ana_a09ef1.get_result('t', 'edot')
ldot_a09ef1 = ana_a09ef1.get_result('t', 'ldot')
eff_a09ef1 = ana_a09ef1.get_result('t', 'eff')

mdot_a09ez5 = ana_a09ez5.get_result('t', 'mdot')
phi_b_a09ez5 = ana_a09ez5.get_result('t', 'phi_b')
edot_a09ez5 = ana_a09ez5.get_result('t', 'edot')
ldot_a09ez5 = ana_a09ez5.get_result('t', 'ldot')
eff_a09ez5 = ana_a09ez5.get_result('t', 'eff')



figs, axs = plt.subplots(2, 1, figsize=(6.4, 10))
axs[0].plot(mdot_a05e00[0], mdot_a05e00[1])
axs[0].plot(mdot_a05ef5[0], mdot_a05ef5[1])
axs[0].plot(mdot_a05ez5[0], mdot_a05ez5[1])
axs[0].plot(mdot_a09e00[0], mdot_a09e00[1])
axs[0].plot(mdot_a09ef1[0], mdot_a09ef1[1])
axs[0].plot(mdot_a09ez5[0], mdot_a09ez5[1])
axs[0].set_ylabel(r'$\dot{M}$')
axs[0].set_yscale('log')
axs[0].set_ylim(1e-5, 1e1)
y_ticks = [1e-5, 1e-3,  1e-1,  1e1]
axs[0].set_yticks(y_ticks)
axs[0].legend([r'$a=0.5, \eta=0.0$', r'$a=0.5, \eta=-0.5$', r'$a=0.5, \eta=0.5$', r'$a=0.94, \eta=0.0$', r'$a=0.94, \eta=-0.1$', r'$a=0.94, \eta=0.5$'])

axs[1].plot(phi_b_a05e00[0], phi_b_a05e00[1])
axs[1].plot(phi_b_a05ef5[0], phi_b_a05ef5[1])
axs[1].plot(phi_b_a05ez5[0], phi_b_a05ez5[1])
axs[1].plot(phi_b_a09e00[0], phi_b_a09e00[1])
axs[1].plot(phi_b_a09ef1[0], phi_b_a09ef1[1])
axs[1].plot(phi_b_a09ez5[0], phi_b_a09ez5[1])
axs[1].set_ylabel(r'$\phi_b$')
axs[1].set_yscale('log')
axs[1].set_ylim(1e-2, 1e1)
y_ticks = [1e-2, 1e-1,  1e0,  1e1]
axs[1].set_yticks(y_ticks)

# axs[2].plot(edot_a05e00[0], edot_a05e00[1])
# axs[2].plot(edot_a05ef5[0], edot_a05ef5[1])
# axs[2].plot(edot_a05ez5[0], edot_a05ez5[1])
# axs[2].plot(edot_a09e00[0], edot_a09e00[1])
# axs[2].plot(edot_a09ef1[0], edot_a09ef1[1])
# axs[2].plot(edot_a09ez5[0], edot_a09ez5[1])
# axs[2].set_ylabel(r'$\dot{E}$')

# axs[3].plot(ldot_a05e00[0], ldot_a05e00[1])
# axs[3].plot(ldot_a05ef5[0], ldot_a05ef5[1])
# axs[3].plot(ldot_a05ez5[0], ldot_a05ez5[1])
# axs[3].plot(ldot_a09e00[0], ldot_a09e00[1])
# axs[3].plot(ldot_a09ef1[0], ldot_a09ef1[1])
# axs[3].plot(ldot_a09ez5[0], ldot_a09ez5[1])
# axs[3].set_ylabel(r'$\dot{L}$')

# axs[4].plot(eff_a05e00[0], eff_a05e00[1])
# axs[4].plot(eff_a05ef5[0], eff_a05ef5[1])
# axs[4].plot(eff_a05ez5[0], eff_a05ez5[1])
# axs[4].plot(eff_a09e00[0], eff_a09e00[1])
# axs[4].plot(eff_a09ef1[0], eff_a09ef1[1])
# axs[4].plot(eff_a09ez5[0], eff_a09ez5[1])
# axs[4].set_ylabel(r'$\left|\dot{E} - \dot{M}\right| / \langle\dot{M}\rangle$')

plt.show()

# %%
figs0, axs0 = plt.subplots(2, 1, figsize=(6.4, 8))
axs0[0].plot(mdot_a05e00[0][::], mdot_a05e00[1][::], '#1f77b4', label=r'$a=0.5, \eta=0.0$')
axs0[0].plot(mdot_a05ef5[0][::], mdot_a05ef5[1][::], '#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
axs0[0].plot(mdot_a05ez5[0][::], mdot_a05ez5[1][::], '#2ca02c', label=r'$a=0.5, \eta=0.5$')
axs0[0].plot(mdot_a09e00[0][::], mdot_a09e00[1][::], '#d62728', label=r'$a=0.94, \eta=0.0$')
axs0[0].plot(mdot_a09ef1[0][::], mdot_a09ef1[1][::], '#9467bd', label=r'$a=0.94, \eta=-0.1$')
axs0[0].plot(mdot_a09ez5[0][::], mdot_a09ez5[1][::], '#8c564b', label=r'$a=0.94, \eta=0.5$')
axs0[0].set_ylabel(r'$\dot{M}$')
axs0[0].set_yscale('log')
axs0[0].set_ylim(1e-3, 1e1)
y_ticks = [1e-3, 1e-1, 1e1]
axs0[0].set_yticks(y_ticks)
axs0[0].legend([r'$a=0.5, \eta=0.0$', r'$a=0.5, \eta=-0.5$', r'$a=0.5, \eta=0.5$', r'$a=0.94, \eta=0.0$', r'$a=0.94, \eta=-0.1$', r'$a=0.94, \eta=0.5$'], loc='lower right')

axs0[1].plot(phi_b_a05e00[0][::], phi_b_a05e00[1][::], '#1f77b4', label=r'$a=0.5, \eta=0.0$')
axs0[1].plot(phi_b_a05ef5[0][::], phi_b_a05ef5[1][::], '#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
axs0[1].plot(phi_b_a05ez5[0][::], phi_b_a05ez5[1][::], '#2ca02c', label=r'$a=0.5, \eta=0.5$')
axs0[1].plot(phi_b_a09e00[0][::], phi_b_a09e00[1][::], '#d62728', label=r'$a=0.94, \eta=0.0$')
axs0[1].plot(phi_b_a09ef1[0][::], phi_b_a09ef1[1][::], '#9467bd', label=r'$a=0.94, \eta=-0.1$')   
axs0[1].plot(phi_b_a09ez5[0][::], phi_b_a09ez5[1][::], '#8c564b', label=r'$a=0.94, \eta=0.5$')
axs0[1].set_ylabel(r'$\phi_b$')
axs0[1].set_yscale('log')
axs0[1].set_ylim(1e-2, 1e1)
y_ticks = [1e-2, 1e-1,  1e0,  1e1]
axs0[1].set_yticks(y_ticks)
axs0[1].set_xlabel(r'$t$')
axs0[1].legend([r'$a=0.5, \eta=0.0$', r'$a=0.5, \eta=-0.5$', r'$a=0.5, \eta=0.5$', r'$a=0.94, \eta=0.0$', r'$a=0.94, \eta=-0.1$', r'$a=0.94, \eta=0.5$'], loc='lower right')
# plt.savefig('kz_analysis_result_t-mdot_phi_b.png', dpi=300)
plt.show()

# %%
av_mdot_a05e00 = np.mean(mdot_a05e00[1], axis=0)
av_mdot_a05ef5 = np.mean(mdot_a05ef5[1], axis=0)
av_mdot_a05ez5 = np.mean(mdot_a05ez5[1], axis=0)
av_mdot_a09e00 = np.mean(mdot_a09e00[1], axis=0)
av_mdot_a09ef1 = np.mean(mdot_a09ef1[1], axis=0)
av_mdot_a09ez5 = np.mean(mdot_a09ez5[1], axis=0)

print("av_mdot_a05e00", av_mdot_a05e00)
print("av_mdot_a05ef5", av_mdot_a05ef5)
print("av_mdot_a05ez5", av_mdot_a05ez5)
print("av_mdot_a09e00", av_mdot_a09e00)
print("av_mdot_a09ef1", av_mdot_a09ef1)
print("av_mdot_a09ez5", av_mdot_a09ez5)
# Out:
# av_mdot_a05e00 0.15426676
# av_mdot_a05ef5 0.20987841
# av_mdot_a05ez5 0.1238812
# av_mdot_a09e00 0.15220675
# av_mdot_a09ef1 0.15245508
# av_mdot_a09ez5 0.1300465

# %%
rav_a05e00 = ana_a05e00.get_ivar('r')
rav_a05ef5 = ana_a05ef5.get_ivar('r')
rav_a05ez5 = ana_a05ez5.get_ivar('r')
rav_a09e00 = ana_a09e00.get_ivar('r')
rav_a09ef1 = ana_a09ef1.get_ivar('r')
rav_a09ez5 = ana_a09ez5.get_ivar('r')

# %%
print("ana_a05e05['t'].shape", ana_a05ef5['t'].shape)
print("ana_a05e05['r'].shape", ana_a05ef5['r'].shape)
print("ana_a05e05['rth'][0].shape", ana_a05ef5['rth'][0].shape)
print("ana_a05e05['rth'][1].shape", ana_a05ef5['rth'][1].shape)
print("ana_a05e05['rtht/rho'].shape", ana_a05ef5['rtht/rho'].shape)
print("ana_a05e05['t/phi_b'].shape", ana_a05ef5['t/phi_b'].shape)
print("ana_a05e05['t/mdot'].shape", ana_a05ef5['t/mdot'].shape)
print("ana_a05e05['r/phi_b'].shape", ana_a05ef5['r/phi_b'].shape)
# Out:
# ana_a05e05['t'].shape (1000,)
# ana_a05e05['r'].shape (288,)
# ana_a05e05['rth'][0].shape (289, 193)
# ana_a05e05['rth'][1].shape (289, 193)
# ana_a05e05['rtht/rho'].shape (1000, 288, 192)
# ana_a05e05['t/phi_b'].shape (1000,)
# ana_a05e05['t/mdot'].shape (1000,)
# ana_a05e05['r/phi_b'].shape (1000,)

# %%
t_start = 500
t_end = 1000

# %%
contour_levels_rho = [-2]
contour_levels_sigma = [0]

# %%
ana_a05e00_ave_rho_max = np.mean(ana_a05e00['rtht/rho'][t_start:t_end, :, :], axis=0).max()
ana_a05ef5_ave_rho_max = np.mean(ana_a05ef5['rtht/rho'][t_start:t_end, :, :], axis=0).max()
ana_a05ez5_ave_rho_max = np.mean(ana_a05ez5['rtht/rho'][t_start:t_end, :, :], axis=0).max()
ana_a09e00_ave_rho_max = np.mean(ana_a09e00['rtht/rho'][t_start:t_end, :, :], axis=0).max()
ana_a09ef1_ave_rho_max = np.mean(ana_a09ef1['rtht/rho'][t_start:t_end, :, :], axis=0).max()
ana_a09ez5_ave_rho_max = np.mean(ana_a09ez5['rtht/rho'][t_start:t_end, :, :], axis=0).max()
print("ana_a05e00_ave_rho_max", ana_a05e00_ave_rho_max)
print("ana_a05ef5_ave_rho_max", ana_a05ef5_ave_rho_max)
print("ana_a05ez5_ave_rho_max", ana_a05ez5_ave_rho_max)
print("ana_a09e00_ave_rho_max", ana_a09e00_ave_rho_max)
print("ana_a09ef1_ave_rho_max", ana_a09ef1_ave_rho_max)
print("ana_a09ez5_ave_rho_max", ana_a09ez5_ave_rho_max)
# Out:
# ana_a05e00_ave_rho_max 0.1696782
# ana_a05ef5_ave_rho_max 0.26659212
# ana_a05ez5_ave_rho_max 0.15793715
# ana_a09e00_ave_rho_max 0.3816183
# ana_a09ef1_ave_rho_max 0.3181473
# ana_a09ez5_ave_rho_max 0.28209487

# %%
X_a05e00 = ana_a05e00['rth'][0][:-1, :-1]
Y_a05e00 = ana_a05e00['rth'][1][:-1, :-1]

r_eh_a05e00 = 1.8660254037844388

rav_rho_a05e00 = np.log10(np.mean(ana_a05e00['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05e00 = np.log10(np.mean(ana_a05e00['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05e00 = np.log10(np.mean(ana_a05e00['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig1 = plt.figure(figsize=(6.8, 6.8*0.8))
# 创建网格规范，减小colorbar的相对高度
gs1 = fig1.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax1_1 = fig1.add_subplot(gs1[1, 0])
ax1_2 = fig1.add_subplot(gs1[1, 1])
ax1_3 = fig1.add_subplot(gs1[1, 2])
axs1 = [ax1_1, ax1_2, ax1_3]

# 密度图
im1_0 = axs1[0].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_rho_a05e00, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs1[0].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)

cs1_0 = axs1[0].contour(X_a05e00, Y_a05e00, rav_rho_a05e00, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs1[0].set_xlim(0, 50)
axs1[0].set_ylim(-50, 50)
axs1[0].set_ylabel(r'$z~[M]$')
axs1[0].set_aspect('equal')
cax1_0 = fig1.add_subplot(gs1[0, 0])
cbar1_0 = plt.colorbar(im1_0, cax=cax1_0, orientation='horizontal')
cbar1_0.ax.xaxis.set_ticks_position('top')
cbar1_0.ax.xaxis.set_label_position('top')
cbar1_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar1_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im1_1 = axs1[1].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_sigma_a05e00,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs1[1].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs1_1 = axs1[1].contour(X_a05e00, Y_a05e00, rav_sigma_a05e00, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs1[1].set_xlim(0, 50)
axs1[1].set_ylim(-50, 50)
axs1[1].set_xlabel(r'$x~[M]$')
axs1[1].set_yticklabels([])
axs1[1].set_aspect('equal')
cax1_1 = fig1.add_subplot(gs1[0, 1])
cbar1_1 = plt.colorbar(im1_1, cax=cax1_1, orientation='horizontal')
cbar1_1.ax.xaxis.set_ticks_position('top')
cbar1_1.ax.xaxis.set_label_position('top')
cbar1_1.set_ticks([-2, -1, 0, 1, 2, 3])   
cbar1_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im1_2 = axs1[2].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_inv_beta_a05e00,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs1[2].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs1[2].set_xlim(0, 50)
axs1[2].set_ylim(-50, 50)
axs1[2].set_yticklabels([])
axs1[2].set_aspect('equal')
cax1_2 = fig1.add_subplot(gs1[0, 2])
cbar1_2 = plt.colorbar(im1_2, cax=cax1_2, orientation='horizontal')
cbar1_2.ax.xaxis.set_ticks_position('top')
cbar1_2.ax.xaxis.set_label_position('top')
cbar1_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar1_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a05e00.png', dpi=300)

# %%
X_a05ef5 = ana_a05ef5['rth'][0][:-1, :-1]
Y_a05ef5 = ana_a05ef5['rth'][1][:-1, :-1]

r_eh_a05ef5 = 1.6714615413885849

rav_rho_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig2 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs2 = fig2.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax2_1 = fig2.add_subplot(gs2[1, 0])
ax2_2 = fig2.add_subplot(gs2[1, 1])
ax2_3 = fig2.add_subplot(gs2[1, 2])
axs2 = [ax2_1, ax2_2, ax2_3]

# 密度图
im2_0 = axs2[0].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_rho_a05ef5, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs2[0].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
# contour_levels_rho = [-2]
cs2_0 = axs2[0].contour(X_a05ef5, Y_a05ef5, rav_rho_a05ef5, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs2[0].set_xlim(0, 50)
axs2[0].set_ylim(-50, 50)
axs2[0].set_aspect('equal')
cax2_0 = fig2.add_subplot(gs2[0, 0])
cbar2_0 = plt.colorbar(im2_0, cax=cax2_0, orientation='horizontal')
cbar2_0.ax.xaxis.set_ticks_position('top')
cbar2_0.ax.xaxis.set_label_position('top')
cbar2_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar2_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im2_1 = axs2[1].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_sigma_a05ef5,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs2[1].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs2_1 = axs2[1].contour(X_a05ef5, Y_a05ef5, rav_sigma_a05ef5, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs2[1].set_xlim(0, 50)
axs2[1].set_ylim(-50, 50)
axs2[1].set_aspect('equal')
cax2_1 = fig2.add_subplot(gs2[0, 1])
cbar2_1 = plt.colorbar(im2_1, cax=cax2_1, orientation='horizontal')
cbar2_1.ax.xaxis.set_ticks_position('top')
cbar2_1.ax.xaxis.set_label_position('top')
cbar2_1.set_ticks([-2, -1, 0, 1, 2, 3])   
cbar2_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im2_2 = axs2[2].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_inv_beta_a05ef5,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs2[2].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[2].set_xlim(0, 50)
axs2[2].set_ylim(-50, 50)
axs2[2].set_aspect('equal')
cax2_2 = fig2.add_subplot(gs2[0, 2])
cbar2_2 = plt.colorbar(im2_2, cax=cax2_2, orientation='horizontal')
cbar2_2.ax.xaxis.set_ticks_position('top')
cbar2_2.ax.xaxis.set_label_position('top')
cbar2_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar2_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a05ef5.png', dpi=300)

# %%
X_a05ez5 = ana_a05ez5['rth'][0][:-1, :-1]
Y_a05ez5 = ana_a05ez5['rth'][1][:-1, :-1]

r_eh_a05ez5 = 2

rav_rho_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig3 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs3 = fig3.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax3_1 = fig3.add_subplot(gs3[1, 0])
ax3_2 = fig3.add_subplot(gs3[1, 1])
ax3_3 = fig3.add_subplot(gs3[1, 2])
axs3 = [ax3_1, ax3_2, ax3_3]

# 密度图
im3_0 = axs3[0].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_rho_a05ez5, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs3[0].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
# contour_levels_rho = [-2]
cs3_0 = axs3[0].contour(X_a05ez5, Y_a05ez5, rav_rho_a05ez5, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs3[0].set_xlim(0, 50)
axs3[0].set_ylim(-50, 50)
axs3[0].set_aspect('equal')
cax3_0 = fig3.add_subplot(gs3[0, 0])
cbar3_0 = plt.colorbar(im3_0, cax=cax3_0, orientation='horizontal')
cbar3_0.ax.xaxis.set_ticks_position('top')
cbar3_0.ax.xaxis.set_label_position('top')
cbar3_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar3_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im3_1 = axs3[1].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_sigma_a05ez5,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs3[1].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs3_1 = axs3[1].contour(X_a05ez5, Y_a05ez5, rav_sigma_a05ez5, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs3[1].set_xlim(0, 50)
axs3[1].set_ylim(-50, 50)
axs3[1].set_aspect('equal')
cax3_1 = fig3.add_subplot(gs3[0, 1])
cbar3_1 = plt.colorbar(im3_1, cax=cax3_1, orientation='horizontal')
cbar3_1.ax.xaxis.set_ticks_position('top')
cbar3_1.ax.xaxis.set_label_position('top')
cbar3_1.set_ticks([-2, -1, 0, 1, 2, 3])   
cbar3_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im3_2 = axs3[2].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_inv_beta_a05ez5,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs3[2].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs3[2].set_xlim(0, 50)
axs3[2].set_ylim(-50, 50)
axs3[2].set_aspect('equal')
cax3_2 = fig3.add_subplot(gs3[0, 2])
cbar3_2 = plt.colorbar(im3_2, cax=cax3_2, orientation='horizontal')
cbar3_2.ax.xaxis.set_ticks_position('top')
cbar3_2.ax.xaxis.set_label_position('top')
cbar3_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar3_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a05ez5.png', dpi=300)

# %%
X_a09e00 = ana_a09e00['rth'][0][:-1, :-1]
Y_a09e00 = ana_a09e00['rth'][1][:-1, :-1]


r_eh_a09e00 = 1.3479852726768762

rav_rho_a09e00 = np.log10(np.mean(ana_a09e00['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09e00 = np.log10(np.mean(ana_a09e00['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09e00 = np.log10(np.mean(ana_a09e00['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig4 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs4 = fig4.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax4_1 = fig4.add_subplot(gs4[1, 0])
ax4_2 = fig4.add_subplot(gs4[1, 1])
ax4_3 = fig4.add_subplot(gs4[1, 2])
axs4 = [ax4_1, ax4_2, ax4_3]

# 密度图
im4_0 = axs4[0].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_rho_a09e00, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs4[0].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
# contour_levels_rho = [-2]
cs4_0 = axs4[0].contour(X_a09e00, Y_a09e00, rav_rho_a09e00, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs4[0].set_xlim(0, 50)
axs4[0].set_ylim(-50, 50)
axs4[0].set_aspect('equal')
cax4_0 = fig4.add_subplot(gs4[0, 0])
cbar4_0 = plt.colorbar(im4_0, cax=cax4_0, orientation='horizontal')
cbar4_0.ax.xaxis.set_ticks_position('top')
cbar4_0.ax.xaxis.set_label_position('top')
cbar4_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar4_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im4_1 = axs4[1].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_sigma_a09e00,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs4[1].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs4_1 = axs4[1].contour(X_a09e00, Y_a09e00, rav_sigma_a09e00, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs4[1].set_xlim(0, 50)
axs4[1].set_ylim(-50, 50)
axs4[1].set_aspect('equal')
cax4_1 = fig4.add_subplot(gs4[0, 1])
cbar4_1 = plt.colorbar(im4_1, cax=cax4_1, orientation='horizontal')
cbar4_1.ax.xaxis.set_ticks_position('top')
cbar4_1.ax.xaxis.set_label_position('top')
cbar4_1.set_ticks([-2, -1, 0, 1, 2, 3])
cbar4_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im4_2 = axs4[2].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_inv_beta_a09e00,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs4[2].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs4[2].set_xlim(0, 50)
axs4[2].set_ylim(-50, 50)
axs4[2].set_aspect('equal')
cax4_2 = fig4.add_subplot(gs4[0, 2])
cbar4_2 = plt.colorbar(im4_2, cax=cax4_2, orientation='horizontal')
cbar4_2.ax.xaxis.set_ticks_position('top')
cbar4_2.ax.xaxis.set_label_position('top')
cbar4_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar4_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a09e00.png', dpi=300)

# %%
X_a09ef1 = ana_a09ef1['rth'][0][:-1, :-1]
Y_a09ef1 = ana_a09ef1['rth'][1][:-1, :-1]


r_eh_a09ef1 = 1.1930710966073588

rav_rho_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig5 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs5 = fig5.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax5_1 = fig5.add_subplot(gs5[1, 0])
ax5_2 = fig5.add_subplot(gs5[1, 1])
ax5_3 = fig5.add_subplot(gs5[1, 2])
axs5 = [ax5_1, ax5_2, ax5_3]

# 密度图
im5_0 = axs5[0].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_rho_a09ef1, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs5[0].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
# contour_levels_rho = [-2]
cs5_0 = axs5[0].contour(X_a09ef1, Y_a09ef1, rav_rho_a09ef1, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs5[0].set_xlim(0, 50)
axs5[0].set_ylim(-50, 50)
axs5[0].set_aspect('equal')
cax5_0 = fig5.add_subplot(gs5[0, 0])
cbar5_0 = plt.colorbar(im5_0, cax=cax5_0, orientation='horizontal')
cbar5_0.ax.xaxis.set_ticks_position('top')
cbar5_0.ax.xaxis.set_label_position('top')
cbar5_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar5_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im5_1 = axs5[1].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_sigma_a09ef1,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs5[1].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs5_1 = axs5[1].contour(X_a09ef1, Y_a09ef1, rav_sigma_a09ef1, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs5[1].set_xlim(0, 50)
axs5[1].set_ylim(-50, 50)
axs5[1].set_aspect('equal')
cax5_1 = fig5.add_subplot(gs5[0, 1])
cbar5_1 = plt.colorbar(im5_1, cax=cax5_1, orientation='horizontal')
cbar5_1.ax.xaxis.set_ticks_position('top')
cbar5_1.ax.xaxis.set_label_position('top')
cbar5_1.set_ticks([-2, -1, 0, 1, 2, 3])
cbar5_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im5_2 = axs5[2].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_inv_beta_a09ef1,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs5[2].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs5[2].set_xlim(0, 50)
axs5[2].set_ylim(-50, 50)
axs5[2].set_aspect('equal')
cax5_2 = fig5.add_subplot(gs5[0, 2])
cbar5_2 = plt.colorbar(im5_2, cax=cax5_2, orientation='horizontal')
cbar5_2.ax.xaxis.set_ticks_position('top')
cbar5_2.ax.xaxis.set_label_position('top')
cbar5_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar5_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a09ef1.png', dpi=300)

# %%
X_a09ez5 = ana_a09ez5['rth'][0][:-1, :-1]
Y_a09ez5 = ana_a09ez5['rth'][1][:-1, :-1]


r_eh_a09ez5 = 1.651093913198195

rav_rho_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))

# 创建带有额外空间的图形
fig6 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs6 = fig6.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax6_1 = fig6.add_subplot(gs6[1, 0])
ax6_2 = fig6.add_subplot(gs6[1, 1])
ax6_3 = fig6.add_subplot(gs6[1, 2])
axs6 = [ax6_1, ax6_2, ax6_3]

# 密度图
im6_0 = axs6[0].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_rho_a09ez5, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs6[0].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
# contour_levels_rho = [-2]
cs6_0 = axs6[0].contour(X_a09ez5, Y_a09ez5, rav_rho_a09ez5, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs6[0].set_xlim(0, 50)
axs6[0].set_ylim(-50, 50)
axs6[0].set_aspect('equal')
cax6_0 = fig6.add_subplot(gs6[0, 0])
cbar6_0 = plt.colorbar(im6_0, cax=cax6_0, orientation='horizontal')
cbar6_0.ax.xaxis.set_ticks_position('top')
cbar6_0.ax.xaxis.set_label_position('top')
cbar6_0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar6_0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im6_1 = axs6[1].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_sigma_a09ez5,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs6[1].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
# contour_levels_sigma = [0]
cs6_1 = axs6[1].contour(X_a09ez5, Y_a09ez5, rav_sigma_a09ez5, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs6[1].set_xlim(0, 50)
axs6[1].set_ylim(-50, 50)
axs6[1].set_aspect('equal')
cax6_1 = fig6.add_subplot(gs6[0, 1])
cbar6_1 = plt.colorbar(im6_1, cax=cax6_1, orientation='horizontal')
cbar6_1.ax.xaxis.set_ticks_position('top')
cbar6_1.ax.xaxis.set_label_position('top')
cbar6_1.set_ticks([-2, -1, 0, 1, 2, 3])
cbar6_1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im6_2 = axs6[2].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_inv_beta_a09ez5,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs6[2].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs6[2].set_xlim(0, 50)
axs6[2].set_ylim(-50, 50)
axs6[2].set_aspect('equal')
cax6_2 = fig6.add_subplot(gs6[0, 2])
cbar6_2 = plt.colorbar(im6_2, cax=cax6_2, orientation='horizontal')
cbar6_2.ax.xaxis.set_ticks_position('top')
cbar6_2.ax.xaxis.set_label_position('top')
cbar6_2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar6_2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

# plt.tight_layout()
# plt.show()
plt.savefig('kz_analysis_result_r-th_a09ez5.png', dpi=300)

# %%
rav_rho_a05e00_counter = np.mean(ana_a05e00['rtht/rho'][t_start:t_end, :, :]/ana_a05e00_ave_rho_max, axis=0)
rav_rho_a05ef5_counter = np.mean(ana_a05ef5['rtht/rho'][t_start:t_end, :, :]/ana_a05ef5_ave_rho_max, axis=0)
rav_rho_a05ez5_counter = np.mean(ana_a05ez5['rtht/rho'][t_start:t_end, :, :]/ana_a05ez5_ave_rho_max, axis=0)
rav_rho_a09e00_counter = np.mean(ana_a09e00['rtht/rho'][t_start:t_end, :, :]/ana_a09e00_ave_rho_max, axis=0)
rav_rho_a09ef1_counter = np.mean(ana_a09ef1['rtht/rho'][t_start:t_end, :, :]/ana_a09ef1_ave_rho_max, axis=0)
rav_rho_a09ez5_counter = np.mean(ana_a09ez5['rtht/rho'][t_start:t_end, :, :]/ana_a09ez5_ave_rho_max, axis=0)

# %%
# 创建新的图像显示3个contour
fig_contour, (ax_contour_rho, ax_contour_sigma) = plt.subplots(1,2,figsize=(8, 8))

# 绘制密度的contour
a05e00_cs_rho = ax_contour_rho.contour(X_a05e00, Y_a05e00, rav_rho_a05e00,
                           levels=[-2], colors='#1f77b4', linestyles='-', 
                           linewidths=2)
a05ef5_cs_rho = ax_contour_rho.contour(X_a05ef5, Y_a05ef5, rav_rho_a05ef5,
                           levels=[-2], colors='#ff7f0e', linestyles='--', 
                           linewidths=2)
a05ez5_cs_rho = ax_contour_rho.contour(X_a05ez5, Y_a05ez5, rav_rho_a05ez5,
                           levels=[-2], colors='#2ca02c', linestyles='--', 
                           linewidths=2)

a09e00_cs_rho = ax_contour_rho.contour(X_a09e00, Y_a09e00, rav_rho_a09e00,
                           levels=[-2], colors='#d62728', linestyles='-', 
                           linewidths=2)
a09ef1_cs_rho = ax_contour_rho.contour(X_a09ef1, Y_a09ef1, rav_rho_a09ef1,
                           levels=[-2], colors='#9467bd', linestyles='--', 
                           linewidths=2)
a09ez5_cs_rho = ax_contour_rho.contour(X_a09ez5, Y_a09ez5, rav_rho_a09ez5,
                           levels=[-2], colors='#8c564b', linestyles='--', 
                           linewidths=2)

# 为每条等值线添加标签

ax_contour_rho.plot([], [], color='#1f77b4', label=r'$a=0.5, \eta=0.0$')
ax_contour_rho.plot([], [], color='#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
ax_contour_rho.plot([], [], color='#2ca02c', label=r'$a=0.5, \eta=0.5$')
ax_contour_rho.plot([], [], color='#d62728', label=r'$a=0.94, \eta=0.0$')
ax_contour_rho.plot([], [], color='#9467bd', label=r'$a=0.94, \eta=-0.1$')
ax_contour_rho.plot([], [], color='#8c564b', label=r'$a=0.94, \eta=0.5$')


# 绘制sigma的contour  
a05e00_cs_sigma = ax_contour_sigma.contour(X_a05e00, Y_a05e00, rav_sigma_a05e00,
                             levels=[0], colors='#1f77b4', linestyles='-',
                             linewidths=2)
a05ef5_cs_sigma = ax_contour_sigma.contour(X_a05ef5, Y_a05ef5, rav_sigma_a05ef5,
                             levels=[0], colors='#ff7f0e', linestyles='--',
                             linewidths=2)
a05ez5_cs_sigma = ax_contour_sigma.contour(X_a05ez5, Y_a05ez5, rav_sigma_a05ez5,
                             levels=[0], colors='#2ca02c', linestyles='--',
                             linewidths=2)
a09e00_cs_sigma = ax_contour_sigma.contour(X_a09e00, Y_a09e00, rav_sigma_a09e00,
                             levels=[0], colors='#d62728', linestyles='-',
                             linewidths=2)
a09ef1_cs_sigma = ax_contour_sigma.contour(X_a09ef1, Y_a09ef1, rav_sigma_a09ef1,
                             levels=[0], colors='#9467bd', linestyles='--',
                             linewidths=2)
a09ez5_cs_sigma = ax_contour_sigma.contour(X_a09ez5, Y_a09ez5, rav_sigma_a09ez5,
                             levels=[0], colors='#8c564b', linestyles='--',
                             linewidths=2)

# 为每条等值线添加标签
ax_contour_sigma.plot([], [], color='#1f77b4', label=r'$a=0.5, \eta=0.0$')
ax_contour_sigma.plot([], [], color='#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
ax_contour_sigma.plot([], [], color='#2ca02c', label=r'$a=0.5, \eta=0.5$')
ax_contour_sigma.plot([], [], color='#d62728', label=r'$a=0.94, \eta=0.0$')
ax_contour_sigma.plot([], [], color='#9467bd', label=r'$a=0.94, \eta=-0.1$')
ax_contour_sigma.plot([], [], color='#8c564b', label=r'$a=0.94, \eta=0.5$')

# 设置坐标轴范围和比例
ax_contour_rho.set_xlim(0, 50)
ax_contour_rho.set_ylim(-50, 50)
ax_contour_rho.set_aspect('equal')
ax_contour_sigma.set_xlim(0, 25)
ax_contour_sigma.set_ylim(-50, 50)
ax_contour_sigma.set_aspect(0.5)

# 添加标题
ax_contour_rho.set_title(r'$\rho=0.01$ contours')
ax_contour_sigma.set_title(r'$\sigma=1$ contours')

# 添加图例
ax_contour_rho.legend(loc='center right')
ax_contour_sigma.legend(loc='center right')
# plt.show()
plt.savefig('kz_analysis_result_r-th_contour.png', dpi=300)

# %%
# 创建新的图像显示3个contour
fig_contour, (ax_contour_rho, ax_contour_sigma) = plt.subplots(1,2,figsize=(8, 8))

# 绘制密度的contour
a05e00_cs_rho = ax_contour_rho.contour(X_a05e00, Y_a05e00, rav_rho_a05e00_counter,
                           levels=[0.01], colors='#1f77b4', linestyles='-', 
                           linewidths=2)
a05ef5_cs_rho = ax_contour_rho.contour(X_a05ef5, Y_a05ef5, rav_rho_a05ef5_counter,
                           levels=[0.01], colors='#ff7f0e', linestyles='--', 
                           linewidths=2)
a05ez5_cs_rho = ax_contour_rho.contour(X_a05ez5, Y_a05ez5, rav_rho_a05ez5_counter,
                           levels=[0.01], colors='#2ca02c', linestyles='--', 
                           linewidths=2)

a09e00_cs_rho = ax_contour_rho.contour(X_a09e00, Y_a09e00, rav_rho_a09e00_counter,
                           levels=[0.01], colors='#d62728', linestyles='-', 
                           linewidths=2)
a09ef1_cs_rho = ax_contour_rho.contour(X_a09ef1, Y_a09ef1, rav_rho_a09ef1_counter,
                           levels=[0.01], colors='#9467bd', linestyles='--', 
                           linewidths=2)
a09ez5_cs_rho = ax_contour_rho.contour(X_a09ez5, Y_a09ez5, rav_rho_a09ez5_counter,
                           levels=[0.01], colors='#8c564b', linestyles='--', 
                           linewidths=2)

# 为每条等值线添加标签

ax_contour_rho.plot([], [], color='#1f77b4', label=r'$a=0.5, \eta=0.0$')
ax_contour_rho.plot([], [], color='#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
ax_contour_rho.plot([], [], color='#2ca02c', label=r'$a=0.5, \eta=0.5$')
ax_contour_rho.plot([], [], color='#d62728', label=r'$a=0.94, \eta=0.0$')
ax_contour_rho.plot([], [], color='#9467bd', label=r'$a=0.94, \eta=-0.1$')
ax_contour_rho.plot([], [], color='#8c564b', label=r'$a=0.94, \eta=0.5$')


# 绘制sigma的contour  
a05e00_cs_sigma = ax_contour_sigma.contour(X_a05e00, Y_a05e00, rav_sigma_a05e00,
                             levels=[0], colors='#1f77b4', linestyles='-',
                             linewidths=2)
a05ef5_cs_sigma = ax_contour_sigma.contour(X_a05ef5, Y_a05ef5, rav_sigma_a05ef5,
                             levels=[0], colors='#ff7f0e', linestyles='--',
                             linewidths=2)
a05ez5_cs_sigma = ax_contour_sigma.contour(X_a05ez5, Y_a05ez5, rav_sigma_a05ez5,
                             levels=[0], colors='#2ca02c', linestyles='--',
                             linewidths=2)
a09e00_cs_sigma = ax_contour_sigma.contour(X_a09e00, Y_a09e00, rav_sigma_a09e00,
                             levels=[0], colors='#d62728', linestyles='-',
                             linewidths=2)
a09ef1_cs_sigma = ax_contour_sigma.contour(X_a09ef1, Y_a09ef1, rav_sigma_a09ef1,
                             levels=[0], colors='#9467bd', linestyles='--',
                             linewidths=2)
a09ez5_cs_sigma = ax_contour_sigma.contour(X_a09ez5, Y_a09ez5, rav_sigma_a09ez5,
                             levels=[0], colors='#8c564b', linestyles='--',
                             linewidths=2)

# 为每条等值线添加标签
ax_contour_sigma.plot([], [], color='#1f77b4', label=r'$a=0.5, \eta=0.0$')
ax_contour_sigma.plot([], [], color='#ff7f0e', label=r'$a=0.5, \eta=-0.5$')
ax_contour_sigma.plot([], [], color='#2ca02c', label=r'$a=0.5, \eta=0.5$')
ax_contour_sigma.plot([], [], color='#d62728', label=r'$a=0.94, \eta=0.0$')
ax_contour_sigma.plot([], [], color='#9467bd', label=r'$a=0.94, \eta=-0.1$')
ax_contour_sigma.plot([], [], color='#8c564b', label=r'$a=0.94, \eta=0.5$')

# 设置坐标轴范围和比例
ax_contour_rho.set_xlim(0, 50)
ax_contour_rho.set_ylim(-50, 50)
ax_contour_rho.set_aspect('equal')
ax_contour_sigma.set_xlim(0, 25)
ax_contour_sigma.set_ylim(-50, 50)
ax_contour_sigma.set_aspect(0.5)

# 添加标题
ax_contour_rho.set_title(r'$\rho=0.01$ contours')
ax_contour_sigma.set_title(r'$\sigma=1$ contours')

# 添加图例
ax_contour_rho.legend(loc='center right')
ax_contour_sigma.legend(loc='center right')
# plt.show()
# plt.savefig('kz_analysis_result_r-th_contour.png', dpi=300)

# %%
ana_a05e00['rt/rho_disk'][::].shape
# Out:
# (1000, 288)

# %%
r_base_a05e00 = ana_a05e00['r']
r_base_a05ef5 = ana_a05ef5['r']
r_base_a05ez5 = ana_a05ez5['r']
r_base_a09e00 = ana_a09e00['r']
r_base_a09ef1 = ana_a09ef1['r']
r_base_a09ez5 = ana_a09ez5['r']

rt_rho_disk_a05e00 = ana_a05e00['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05e00 = ana_a05e00['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a05ef5 = ana_a05ef5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05ef5 = ana_a05ef5['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a05ez5 = ana_a05ez5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05ez5 = ana_a05ez5['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09e00 = ana_a09e00['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09e00 = ana_a09e00['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09ef1 = ana_a09ef1['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09ef1 = ana_a09ef1['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09ez5 = ana_a09ez5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09ez5 = ana_a09ez5['rt/rho_notdisk'][t_start:t_end,:]

# fig_rho, (ax_rho_disk, ax_rho_nodisk, ax_rho_all) = plt.subplots(3,1,figsize=(8, 6))
# ax_rho_disk.plot(r_base_a05e00, np.mean(rt_rho_disk_a05e00, axis=0), label='a05e00')
# ax_rho_disk.plot(r_base_a05e05, np.mean(rt_rho_disk_a05e05, axis=0), label='a05e05')
# ax_rho_disk.plot(r_base_a09e00, np.mean(rt_rho_disk_a09e00, axis=0), label='a09e00')
# ax_rho_disk.plot(r_base_a09e05, np.mean(rt_rho_disk_a09e05, axis=0), label='a09e05')
# ax_rho_disk.legend()
# ax_rho_disk.set_xscale('log')
# ax_rho_nodisk.plot(r_base_a05e00, np.mean(rt_rho_notdisk_a05e00, axis=0), label='a05e00')
# ax_rho_nodisk.plot(r_base_a05e05, np.mean(rt_rho_notdisk_a05e05, axis=0), label='a05e05')
# ax_rho_nodisk.plot(r_base_a09e00, np.mean(rt_rho_notdisk_a09e00, axis=0), label='a09e00')
# ax_rho_nodisk.plot(r_base_a09e05, np.mean(rt_rho_notdisk_a09e05, axis=0), label='a09e05')
# ax_rho_nodisk.legend()
# ax_rho_nodisk.set_xscale('log')

rt_rht_all_a05e00 = np.mean(rt_rho_disk_a05e00, axis=0)  #+ np.mean(rt_rho_notdisk_a05e00, axis=0)
rt_rht_all_a05ef5 = np.mean(rt_rho_disk_a05ef5, axis=0)  #+ np.mean(rt_rho_notdisk_a05ef5, axis=0)
rt_rht_all_a05ez5 = np.mean(rt_rho_disk_a05ez5, axis=0)  #+ np.mean(rt_rho_notdisk_a05ez5, axis=0)
rt_rht_all_a09e00 = np.mean(rt_rho_disk_a09e00, axis=0)  #+ np.mean(rt_rho_notdisk_a09e00, axis=0)
rt_rht_all_a09ef1 = np.mean(rt_rho_disk_a09ef1, axis=0)  #+ np.mean(rt_rho_notdisk_a09ef1, axis=0)
rt_rht_all_a09ez5 = np.mean(rt_rho_disk_a09ez5, axis=0)  #+ np.mean(rt_rho_notdisk_a09ez5, axis=0)

rt_rht_all_a05e00_max = np.max(rt_rht_all_a05e00)
rt_rht_all_a05ef5_max = np.max(rt_rht_all_a05ef5)
rt_rht_all_a05ez5_max = np.max(rt_rht_all_a05ez5)
rt_rht_all_a09e00_max = np.max(rt_rht_all_a09e00)
rt_rht_all_a09ef1_max = np.max(rt_rht_all_a09ef1)
rt_rht_all_a09ez5_max = np.max(rt_rht_all_a09ez5)

rt_rht_all_a05e00_max_pos = np.argmax(rt_rht_all_a05e00)
rt_rht_all_a05ef5_max_pos = np.argmax(rt_rht_all_a05ef5)
rt_rht_all_a05ez5_max_pos = np.argmax(rt_rht_all_a05ez5)
rt_rht_all_a09e00_max_pos = np.argmax(rt_rht_all_a09e00)
rt_rht_all_a09ef1_max_pos = np.argmax(rt_rht_all_a09ef1)
rt_rht_all_a09ez5_max_pos = np.argmax(rt_rht_all_a09ez5)

fig_rho, ax_rho_all = plt.subplots(1,1,figsize=(6, 4))
ax_rho_all.plot(r_base_a05e00[5:], (rt_rht_all_a05e00/rt_rht_all_a05e00_max)[5:], label=r'$a=0.5, \eta=0.0$', linestyle='-', color='#1f77b4')
ax_rho_all.axvline(r_base_a05e00[rt_rht_all_a05e00_max_pos], ymin = 0.0, ymax = 1.0, color='#1f77b4')
ax_rho_all.plot(r_base_a05ef5[5:], (rt_rht_all_a05ef5/rt_rht_all_a05ef5_max)[5:], label=r'$a=0.5, \eta=-0.5$', linestyle='--', color='#ff7f0e')
ax_rho_all.axvline(r_base_a05ef5[rt_rht_all_a05ef5_max_pos], ymin = 0.0, ymax = 1.0, color='#ff7f0e')
ax_rho_all.plot(r_base_a05ez5[5:], (rt_rht_all_a05ez5/rt_rht_all_a05ez5_max)[5:], label=r'$a=0.5, \eta=0.5$', linestyle='--', color='#2ca02c')
ax_rho_all.axvline(r_base_a05ez5[rt_rht_all_a05ez5_max_pos], ymin = 0.0, ymax = 1.0, color='#2ca02c')

ax_rho_all.plot(r_base_a09e00[5:], (rt_rht_all_a09e00/rt_rht_all_a09e00_max)[5:], label=r'$a=0.9, \eta=0.0$', linestyle='-', color='#d62728')
ax_rho_all.axvline(r_base_a09e00[rt_rht_all_a09e00_max_pos], ymin = 0.0, ymax = 1.0, color='#d62728')
ax_rho_all.plot(r_base_a09ef1[5:], (rt_rht_all_a09ef1/rt_rht_all_a09ef1_max)[5:], label=r'$a=0.9, \eta=-0.1$', linestyle='--', color='#9467bd')
ax_rho_all.axvline(r_base_a09ef1[rt_rht_all_a09ef1_max_pos], ymin = 0.0, ymax = 1.0, color='#9467bd')
ax_rho_all.plot(r_base_a09ez5[5:], (rt_rht_all_a09ez5/rt_rht_all_a09ez5_max)[5:], label=r'$a=0.9, \eta=0.5$', linestyle='--', color='#8c564b')
ax_rho_all.axvline(r_base_a09ez5[rt_rht_all_a09ez5_max_pos], ymin = 0.0, ymax = 1.0, color='#8c564b')
ax_rho_all.legend()
ax_rho_all.set_xscale('log')
ax_rho_all.set_xlabel(r'$r$')
ax_rho_all.set_ylabel(r'$\langle\rho\rangle / \langle\rho\rangle_{max}$')  #_{t,\theta,\phi}

ax_rho_all.set_ylim(0, 1.1)
ax_rho_all.set_xlim(0, 20)

plt.savefig('kz_analysis_result_r-t_rho_all.png', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_134138/4203757796.py:76: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax_rho_all.set_xlim(0, 20)

# %%
t_start = 500
t_end = 1000

r_base_a05e00 = ana_a05e00['r']
r_base_a05ef5 = ana_a05ef5['r']
r_base_a05ez5 = ana_a05ez5['r']
r_base_a09e00 = ana_a09e00['r']
r_base_a09ef1 = ana_a09ef1['r']
r_base_a09ez5 = ana_a09ez5['r']

rt_rho_disk_a05e00 = ana_a05e00['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05e00 = ana_a05e00['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a05ef5 = ana_a05ef5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05ef5 = ana_a05ef5['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a05ez5 = ana_a05ez5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a05ez5 = ana_a05ez5['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09e00 = ana_a09e00['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09e00 = ana_a09e00['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09ef1 = ana_a09ef1['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09ef1 = ana_a09ef1['rt/rho_notdisk'][t_start:t_end,:]
rt_rho_disk_a09ez5 = ana_a09ez5['rt/rho_disk'][t_start:t_end,:]
rt_rho_notdisk_a09ez5 = ana_a09ez5['rt/rho_notdisk'][t_start:t_end,:]

# fig_rho, (ax_rho_disk, ax_rho_nodisk, ax_rho_all) = plt.subplots(3,1,figsize=(8, 6))
# ax_rho_disk.plot(r_base_a05e00, np.mean(rt_rho_disk_a05e00, axis=0), label='a05e00')
# ax_rho_disk.plot(r_base_a05e05, np.mean(rt_rho_disk_a05e05, axis=0), label='a05e05')
# ax_rho_disk.plot(r_base_a09e00, np.mean(rt_rho_disk_a09e00, axis=0), label='a09e00')
# ax_rho_disk.plot(r_base_a09e05, np.mean(rt_rho_disk_a09e05, axis=0), label='a09e05')
# ax_rho_disk.legend()
# ax_rho_disk.set_xscale('log')
# ax_rho_nodisk.plot(r_base_a05e00, np.mean(rt_rho_notdisk_a05e00, axis=0), label='a05e00')
# ax_rho_nodisk.plot(r_base_a05e05, np.mean(rt_rho_notdisk_a05e05, axis=0), label='a05e05')
# ax_rho_nodisk.plot(r_base_a09e00, np.mean(rt_rho_notdisk_a09e00, axis=0), label='a09e00')
# ax_rho_nodisk.plot(r_base_a09e05, np.mean(rt_rho_notdisk_a09e05, axis=0), label='a09e05')
# ax_rho_nodisk.legend()
# ax_rho_nodisk.set_xscale('log')

rt_rht_all_a05e00 = np.mean(rt_rho_disk_a05e00, axis=0) + np.mean(rt_rho_notdisk_a05e00, axis=0)
rt_rht_all_a05ef5 = np.mean(rt_rho_disk_a05ef5, axis=0) + np.mean(rt_rho_notdisk_a05ef5, axis=0)
rt_rht_all_a05ez5 = np.mean(rt_rho_disk_a05ez5, axis=0) + np.mean(rt_rho_notdisk_a05ez5, axis=0)
rt_rht_all_a09e00 = np.mean(rt_rho_disk_a09e00, axis=0) + np.mean(rt_rho_notdisk_a09e00, axis=0)
rt_rht_all_a09ef1 = np.mean(rt_rho_disk_a09ef1, axis=0) + np.mean(rt_rho_notdisk_a09ef1, axis=0)
rt_rht_all_a09ez5 = np.mean(rt_rho_disk_a09ez5, axis=0) + np.mean(rt_rho_notdisk_a09ez5, axis=0)

rt_rht_all_a05e00_max = np.max(rt_rht_all_a05e00)
rt_rht_all_a05ef5_max = np.max(rt_rht_all_a05ef5)
rt_rht_all_a05ez5_max = np.max(rt_rht_all_a05ez5)
rt_rht_all_a09e00_max = np.max(rt_rht_all_a09e00)
rt_rht_all_a09ef1_max = np.max(rt_rht_all_a09ef1)
rt_rht_all_a09ez5_max = np.max(rt_rht_all_a09ez5)

rt_rht_all_a05e00_max_pos = np.argmax(rt_rht_all_a05e00)
rt_rht_all_a05ef5_max_pos = np.argmax(rt_rht_all_a05ef5)
rt_rht_all_a05ez5_max_pos = np.argmax(rt_rht_all_a05ez5)
rt_rht_all_a09e00_max_pos = np.argmax(rt_rht_all_a09e00)
rt_rht_all_a09ef1_max_pos = np.argmax(rt_rht_all_a09ef1)
rt_rht_all_a09ez5_max_pos = np.argmax(rt_rht_all_a09ez5)

fig_rho, ax_rho_all = plt.subplots(2,1,figsize=(6, 4), sharex=True)
ax_rho_all[0].plot(r_base_a05e00, rt_rht_all_a05e00, label=r'$a=0.5, \eta=0.0$', linestyle='-', color='#1f77b4')
ax_rho_all[0].axvline(r_base_a05e00[rt_rht_all_a05e00_max_pos], color='#1f77b4', linestyle='-')
ax_rho_all[0].plot(r_base_a05ef5, rt_rht_all_a05ef5, label=r'$a=0.5, \eta=-0.5$', linestyle='-', color='#ff7f0e')
ax_rho_all[0].axvline(r_base_a05ef5[rt_rht_all_a05ef5_max_pos], color='#ff7f0e', linestyle='-')
ax_rho_all[0].plot(r_base_a05ez5, rt_rht_all_a05ez5, label=r'$a=0.5, \eta=0.5$', linestyle='-', color='#2ca02c')
ax_rho_all[0].axvline(r_base_a05ez5[rt_rht_all_a05ez5_max_pos], color='#2ca02c', linestyle='-')

ax_rho_all[0].set_ylim(0, 0.25)
ax_rho_all[0].set_ylabel(r'$log_{10}\langle\rho\rangle_{t,\theta,\phi}$')
ax_rho_all[0].legend()


ax_rho_all[1].plot(r_base_a09e00, rt_rht_all_a09e00, label=r'$a=0.9, \eta=0.0$', linestyle='-', color='#d62728')
ax_rho_all[1].axvline(r_base_a09e00[rt_rht_all_a09e00_max_pos], color='#d62728', linestyle='-')
ax_rho_all[1].plot(r_base_a09ef1, rt_rht_all_a09ef1, label=r'$a=0.9, \eta=-0.1$', linestyle='-', color='#9467bd')
ax_rho_all[1].axvline(r_base_a09ef1[rt_rht_all_a09ef1_max_pos], color='#9467bd', linestyle='-')
ax_rho_all[1].plot(r_base_a09ez5, rt_rht_all_a09ez5, label=r'$a=0.9, \eta=0.5$', linestyle='-', color='#8c564b')
ax_rho_all[1].axvline(r_base_a09ez5[rt_rht_all_a09ez5_max_pos], color='#8c564b', linestyle='-')
ax_rho_all[1].legend()
ax_rho_all[1].set_xscale('log')
ax_rho_all[1].set_xlabel(r'$r$')
ax_rho_all[1].set_ylabel(r'$log_{10}\langle\rho\rangle_{t,\theta,\phi}$')

ax_rho_all[1].set_xlim(1, 50)
ax_rho_all[1].set_ylim(0, 0.25)

# plt.savefig('kz_analysis_result_r-t_rho_all.png', dpi=300)
plt.show()

# %%
rt_FM_all_a05e00 = ana_a05e00['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a05e00 = ana_a05e00['rt/FM_disk'][t_start:t_end,:]
rt_FM_all_a05ef5 = ana_a05ef5['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a05ef5 = ana_a05ef5['rt/FM_disk'][t_start:t_end,:]
rt_FM_all_a05ez5 = ana_a05ez5['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a05ez5 = ana_a05ez5['rt/FM_disk'][t_start:t_end,:]
rt_FM_all_a09e00 = ana_a09e00['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a09e00 = ana_a09e00['rt/FM_disk'][t_start:t_end,:]
rt_FM_all_a09ef1 = ana_a09ef1['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a09ef1 = ana_a09ef1['rt/FM_disk'][t_start:t_end,:]
rt_FM_all_a09ez5 = ana_a09ez5['rt/FM_all'][t_start:t_end,:]
rt_FM_disk_a09ez5 = ana_a09ez5['rt/FM_disk'][t_start:t_end,:]
fig_FM, (ax_FM_all, ax_FM_disk) = plt.subplots(2,1,figsize=(8, 4))
ax_FM_all.plot(r_base_a05e00, np.mean(rt_FM_all_a05e00, axis=0), label='a05e00')
ax_FM_all.plot(r_base_a05ef5, np.mean(rt_FM_all_a05ef5, axis=0), label='a05ef5')
ax_FM_all.plot(r_base_a05ez5, np.mean(rt_FM_all_a05ez5, axis=0), label='a05ez5')
ax_FM_all.plot(r_base_a09e00, np.mean(rt_FM_all_a09e00, axis=0), label='a09e00')
ax_FM_all.plot(r_base_a09ef1, np.mean(rt_FM_all_a09ef1, axis=0), label='a09ef1')
ax_FM_all.plot(r_base_a09ez5, np.mean(rt_FM_all_a09ez5, axis=0), label='a09ez5')
ax_FM_all.legend()
ax_FM_all.set_xscale('log')
ax_FM_disk.plot(r_base_a05e00, np.mean(rt_FM_disk_a05e00, axis=0), label='a05e00')
ax_FM_disk.plot(r_base_a05ef5, np.mean(rt_FM_disk_a05ef5, axis=0), label='a05ef5')
ax_FM_disk.plot(r_base_a05ez5, np.mean(rt_FM_disk_a05ez5, axis=0), label='a05ez5')
ax_FM_disk.plot(r_base_a09e00, np.mean(rt_FM_disk_a09e00, axis=0), label='a09e00')
ax_FM_disk.plot(r_base_a09ef1, np.mean(rt_FM_disk_a09ef1, axis=0), label='a09ef1')
ax_FM_disk.plot(r_base_a09ez5, np.mean(rt_FM_disk_a09ez5, axis=0), label='a09ez5')
ax_FM_disk.legend()
ax_FM_disk.set_xscale('log')
plt.show()

# %%
rt_outflow_a05e00 = ana_a05e00['rt/outflow'][t_start:t_end,:]
rt_outflow_a05ef5 = ana_a05ef5['rt/outflow'][t_start:t_end,:]
rt_outflow_a05ez5 = ana_a05ez5['rt/outflow'][t_start:t_end,:]
rt_outflow_a09e00 = ana_a09e00['rt/outflow'][t_start:t_end,:]
rt_outflow_a09ef1 = ana_a09ef1['rt/outflow'][t_start:t_end,:]
rt_outflow_a09ez5 = ana_a09ez5['rt/outflow'][t_start:t_end,:]
fig_outflow, ax_outflow = plt.subplots(1,1,figsize=(8, 4))
ax_outflow.plot(r_base_a05e00, np.mean(rt_outflow_a05e00, axis=0), label='a05e00')
ax_outflow.plot(r_base_a05ef5, np.mean(rt_outflow_a05ef5, axis=0), label='a05ef5')
ax_outflow.plot(r_base_a05ez5, np.mean(rt_outflow_a05ez5, axis=0), label='a05ez5')
ax_outflow.plot(r_base_a09e00, np.mean(rt_outflow_a09e00, axis=0), label='a09e00')
ax_outflow.plot(r_base_a09ef1, np.mean(rt_outflow_a09ef1, axis=0), label='a09ef1')
ax_outflow.plot(r_base_a09ez5, np.mean(rt_outflow_a09ez5, axis=0), label='a09ez5')
ax_outflow.legend()
ax_outflow.set_xscale('log')
ax_outflow.set_xlim(1, 50)
plt.show()

# %%
t_start = 500
t_end = 1000

r_base_a05e00 = ana_a05e00['r']
r_base_a05ef5 = ana_a05ef5['r']
r_base_a05ez5 = ana_a05ez5['r']
r_base_a09e00 = ana_a09e00['r']
r_base_a09ef1 = ana_a09ef1['r']
r_base_a09ez5 = ana_a09ez5['r']

rt_u3_disk_a05e00 = ana_a05e00['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a05e00 = ana_a05e00['rt/u^3_notdisk'][t_start:t_end,:]
rt_u3_disk_a05ef5 = ana_a05ef5['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a05ef5 = ana_a05ef5['rt/u^3_notdisk'][t_start:t_end,:]
rt_u3_disk_a05ez5 = ana_a05ez5['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a05ez5 = ana_a05ez5['rt/u^3_notdisk'][t_start:t_end,:]
rt_u3_disk_a09e00 = ana_a09e00['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a09e00 = ana_a09e00['rt/u^3_notdisk'][t_start:t_end,:]
rt_u3_disk_a09ef1 = ana_a09ef1['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a09ef1 = ana_a09ef1['rt/u^3_notdisk'][t_start:t_end,:]
rt_u3_disk_a09ez5 = ana_a09ez5['rt/u^3_disk'][t_start:t_end,:]
rt_u3_notdisk_a09ez5 = ana_a09ez5['rt/u^3_notdisk'][t_start:t_end,:]

# fig_rho, (ax_rho_disk, ax_rho_nodisk, ax_rho_all) = plt.subplots(3,1,figsize=(8, 6))
# ax_rho_disk.plot(r_base_a05e00, np.mean(rt_rho_disk_a05e00, axis=0), label='a05e00')
# ax_rho_disk.plot(r_base_a05e05, np.mean(rt_rho_disk_a05e05, axis=0), label='a05e05')
# ax_rho_disk.plot(r_base_a09e00, np.mean(rt_rho_disk_a09e00, axis=0), label='a09e00')
# ax_rho_disk.plot(r_base_a09e05, np.mean(rt_rho_disk_a09e05, axis=0), label='a09e05')
# ax_rho_disk.legend()
# ax_rho_disk.set_xscale('log')
# ax_rho_nodisk.plot(r_base_a05e00, np.mean(rt_rho_notdisk_a05e00, axis=0), label='a05e00')
# ax_rho_nodisk.plot(r_base_a05e05, np.mean(rt_rho_notdisk_a05e05, axis=0), label='a05e05')
# ax_rho_nodisk.plot(r_base_a09e00, np.mean(rt_rho_notdisk_a09e00, axis=0), label='a09e00')
# ax_rho_nodisk.plot(r_base_a09e05, np.mean(rt_rho_notdisk_a09e05, axis=0), label='a09e05')
# ax_rho_nodisk.legend()
# ax_rho_nodisk.set_xscale('log')

rt_u3_all_a05e00 = np.mean(rt_u3_disk_a05e00, axis=0) + np.mean(rt_u3_notdisk_a05e00, axis=0)
rt_u3_all_a05ef5 = np.mean(rt_u3_disk_a05ef5, axis=0) + np.mean(rt_u3_notdisk_a05ef5, axis=0)
rt_u3_all_a05ez5 = np.mean(rt_u3_disk_a05ez5, axis=0) + np.mean(rt_u3_notdisk_a05ez5, axis=0)
rt_u3_all_a09e00 = np.mean(rt_u3_disk_a09e00, axis=0) + np.mean(rt_u3_notdisk_a09e00, axis=0)
rt_u3_all_a09ef1 = np.mean(rt_u3_disk_a09ef1, axis=0) + np.mean(rt_u3_notdisk_a09ef1, axis=0)
rt_u3_all_a09ez5 = np.mean(rt_u3_disk_a09ez5, axis=0) + np.mean(rt_u3_notdisk_a09ez5, axis=0)

rt_u3_all_a05e00_max = np.max(rt_u3_all_a05e00)
rt_u3_all_a05ef5_max = np.max(rt_u3_all_a05ef5)
rt_u3_all_a05ez5_max = np.max(rt_u3_all_a05ez5)
rt_u3_all_a09e00_max = np.max(rt_u3_all_a09e00)
rt_u3_all_a09ef1_max = np.max(rt_u3_all_a09ef1)
rt_u3_all_a09ez5_max = np.max(rt_u3_all_a09ez5)

rt_u3_all_a05e00_max_pos = np.argmax(rt_u3_all_a05e00)
rt_u3_all_a05ef5_max_pos = np.argmax(rt_u3_all_a05ef5)
rt_u3_all_a05ez5_max_pos = np.argmax(rt_u3_all_a05ez5)
rt_u3_all_a09e00_max_pos = np.argmax(rt_u3_all_a09e00)
rt_u3_all_a09ef1_max_pos = np.argmax(rt_u3_all_a09ef1)
rt_u3_all_a09ez5_max_pos = np.argmax(rt_u3_all_a09ez5)

fig_u3, ax_u3_all = plt.subplots(2,1,figsize=(6, 4), sharex=True)
ax_u3_all[0].plot(r_base_a05e00[5:], rt_u3_all_a05e00[5:], label=r'$a=0.5, \eta=0.0$', linestyle='-', color='#1f77b4')
# ax_u3_all[0].axvline(r_base_a05e00[rt_u3_all_a05e00_max_pos], color='#1f77b4', linestyle='-')
ax_u3_all[0].plot(r_base_a05ef5[5:], rt_u3_all_a05ef5[5:], label=r'$a=0.5, \eta=-0.5$', linestyle='-', color='#ff7f0e')
# ax_u3_all[0].axvline(r_base_a05ef5[rt_u3_all_a05ef5_max_pos], color='#ff7f0e', linestyle='-')
ax_u3_all[0].plot(r_base_a05ez5[5:], rt_u3_all_a05ez5[5:], label=r'$a=0.5, \eta=0.5$', linestyle='-', color='#2ca02c')
# ax_u3_all[0].axvline(r_base_a05ez5[rt_u3_all_a05ez5_max_pos], color='#2ca02c', linestyle='-')

# ax_u3_all[0].set_ylim(0, 0.25)
ax_u3_all[0].set_ylabel(r'$u_3$')
ax_u3_all[0].legend()


ax_u3_all[1].plot(r_base_a09e00[5:], rt_u3_all_a09e00[5:], label=r'$a=0.9, \eta=0.0$', linestyle='-', color='#d62728')
# ax_u3_all[1].axvline(r_base_a09e00[rt_u3_all_a09e00_max_pos], color='#d62728', linestyle='-')
ax_u3_all[1].plot(r_base_a09ef1[5:], rt_u3_all_a09ef1[5:], label=r'$a=0.9, \eta=-0.1$', linestyle='-', color='#9467bd')
# ax_u3_all[1].axvline(r_base_a09ef1[rt_u3_all_a09ef1_max_pos], color='#9467bd', linestyle='-')
ax_u3_all[1].plot(r_base_a09ez5[5:], rt_u3_all_a09ez5[5:], label=r'$a=0.9, \eta=0.5$', linestyle='-', color='#8c564b')
# ax_u3_all[1].axvline(r_base_a09ez5[rt_u3_all_a09ez5_max_pos], color='#8c564b', linestyle='-')
ax_u3_all[1].legend()
ax_u3_all[1].set_xscale('log')
# ax_u3_all[1].set_yscale('log')
ax_u3_all[1].set_xlabel(r'$r$')
ax_u3_all[1].set_ylabel(r'$u_3$')

ax_u3_all[1].set_xlim(1, 20)
# ax_u3_all[1].set_ylim(0, 20)

# plt.savefig('kz_analysis_result_r-t_rho_all.png', dpi=300)
plt.show()

# %%
t_start = 500
t_end = 1000

r_base_a05e00 = ana_a05e00['r']
r_base_a05ef5 = ana_a05ef5['r']
r_base_a05ez5 = ana_a05ez5['r']
r_base_a09e00 = ana_a09e00['r']
r_base_a09ef1 = ana_a09ef1['r']
r_base_a09ez5 = ana_a09ez5['r']

rt_ur_disk_a05e00 = ana_a05e00['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a05e00 = ana_a05e00['rt/u^r_notdisk'][t_start:t_end,:]
rt_ur_disk_a05ef5 = ana_a05ef5['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a05ef5 = ana_a05ef5['rt/u^r_notdisk'][t_start:t_end,:]
rt_ur_disk_a05ez5 = ana_a05ez5['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a05ez5 = ana_a05ez5['rt/u^r_notdisk'][t_start:t_end,:]
rt_ur_disk_a09e00 = ana_a09e00['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a09e00 = ana_a09e00['rt/u^r_notdisk'][t_start:t_end,:]
rt_ur_disk_a09ef1 = ana_a09ef1['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a09ef1 = ana_a09ef1['rt/u^r_notdisk'][t_start:t_end,:]
rt_ur_disk_a09ez5 = ana_a09ez5['rt/u^r_disk'][t_start:t_end,:]
rt_ur_notdisk_a09ez5 = ana_a09ez5['rt/u^r_notdisk'][t_start:t_end,:]

# fig_rho, (ax_rho_disk, ax_rho_nodisk, ax_rho_all) = plt.subplots(3,1,figsize=(8, 6))
# ax_rho_disk.plot(r_base_a05e00, np.mean(rt_rho_disk_a05e00, axis=0), label='a05e00')
# ax_rho_disk.plot(r_base_a05e05, np.mean(rt_rho_disk_a05e05, axis=0), label='a05e05')
# ax_rho_disk.plot(r_base_a09e00, np.mean(rt_rho_disk_a09e00, axis=0), label='a09e00')
# ax_rho_disk.plot(r_base_a09e05, np.mean(rt_rho_disk_a09e05, axis=0), label='a09e05')
# ax_rho_disk.legend()
# ax_rho_disk.set_xscale('log')
# ax_rho_nodisk.plot(r_base_a05e00, np.mean(rt_rho_notdisk_a05e00, axis=0), label='a05e00')
# ax_rho_nodisk.plot(r_base_a05e05, np.mean(rt_rho_notdisk_a05e05, axis=0), label='a05e05')
# ax_rho_nodisk.plot(r_base_a09e00, np.mean(rt_rho_notdisk_a09e00, axis=0), label='a09e00')
# ax_rho_nodisk.plot(r_base_a09e05, np.mean(rt_rho_notdisk_a09e05, axis=0), label='a09e05')
# ax_rho_nodisk.legend()
# ax_rho_nodisk.set_xscale('log')

rt_ur_all_a05e00 = np.mean(rt_ur_disk_a05e00, axis=0) + np.mean(rt_ur_notdisk_a05e00, axis=0)
rt_ur_all_a05ef5 = np.mean(rt_ur_disk_a05ef5, axis=0) + np.mean(rt_ur_notdisk_a05ef5, axis=0)
rt_ur_all_a05ez5 = np.mean(rt_ur_disk_a05ez5, axis=0) + np.mean(rt_ur_notdisk_a05ez5, axis=0)
rt_ur_all_a09e00 = np.mean(rt_ur_disk_a09e00, axis=0) + np.mean(rt_ur_notdisk_a09e00, axis=0)
rt_ur_all_a09ef1 = np.mean(rt_ur_disk_a09ef1, axis=0) + np.mean(rt_ur_notdisk_a09ef1, axis=0)
rt_ur_all_a09ez5 = np.mean(rt_ur_disk_a09ez5, axis=0) + np.mean(rt_ur_notdisk_a09ez5, axis=0)

rt_ur_all_a05e00_max = np.max(rt_ur_all_a05e00)
rt_ur_all_a05ef5_max = np.max(rt_ur_all_a05ef5)
rt_ur_all_a05ez5_max = np.max(rt_ur_all_a05ez5)
rt_ur_all_a09e00_max = np.max(rt_ur_all_a09e00)
rt_ur_all_a09ef1_max = np.max(rt_ur_all_a09ef1)
rt_ur_all_a09ez5_max = np.max(rt_ur_all_a09ez5)

rt_ur_all_a05e00_max_pos = np.argmax(rt_ur_all_a05e00)
rt_ur_all_a05ef5_max_pos = np.argmax(rt_ur_all_a05ef5)
rt_ur_all_a05ez5_max_pos = np.argmax(rt_ur_all_a05ez5)
rt_ur_all_a09e00_max_pos = np.argmax(rt_ur_all_a09e00)
rt_ur_all_a09ef1_max_pos = np.argmax(rt_ur_all_a09ef1)
rt_ur_all_a09ez5_max_pos = np.argmax(rt_ur_all_a09ez5)

fig_ur, ax_ur_all = plt.subplots(2,1,figsize=(6, 4), sharex=True)
ax_ur_all[0].plot(r_base_a05e00[5:], rt_ur_all_a05e00[5:], label=r'$a=0.5, \eta=0.0$', linestyle='-', color='#1f77b4')
# ax_u3_all[0].axvline(r_base_a05e00[rt_u3_all_a05e00_max_pos], color='#1f77b4', linestyle='-')
ax_ur_all[0].plot(r_base_a05ef5[5:], rt_ur_all_a05ef5[5:], label=r'$a=0.5, \eta=-0.5$', linestyle='-', color='#ff7f0e')
# ax_u3_all[0].axvline(r_base_a05ef5[rt_u3_all_a05ef5_max_pos], color='#ff7f0e', linestyle='-')
ax_ur_all[0].plot(r_base_a05ez5[5:], rt_ur_all_a05ez5[5:], label=r'$a=0.5, \eta=0.5$', linestyle='-', color='#2ca02c')
# ax_u3_all[0].axvline(r_base_a05ez5[rt_u3_all_a05ez5_max_pos], color='#2ca02c', linestyle='-')

# ax_u3_all[0].set_ylim(0, 0.25)
ax_ur_all[0].set_ylabel(r'$u_r$')
ax_ur_all[0].legend()


ax_ur_all[1].plot(r_base_a09e00[5:], rt_ur_all_a09e00[5:], label=r'$a=0.9, \eta=0.0$', linestyle='-', color='#d62728')
# ax_u3_all[1].axvline(r_base_a09e00[rt_u3_all_a09e00_max_pos], color='#d62728', linestyle='-')
ax_ur_all[1].plot(r_base_a09ef1[5:], rt_ur_all_a09ef1[5:], label=r'$a=0.9, \eta=-0.1$', linestyle='-', color='#9467bd')
# ax_u3_all[1].axvline(r_base_a09ef1[rt_u3_all_a09ef1_max_pos], color='#9467bd', linestyle='-')
ax_ur_all[1].plot(r_base_a09ez5[5:], rt_ur_all_a09ez5[5:], label=r'$a=0.9, \eta=0.5$', linestyle='-', color='#8c564b')
# ax_u3_all[1].axvline(r_base_a09ez5[rt_u3_all_a09ez5_max_pos], color='#8c564b', linestyle='-')
ax_ur_all[1].legend()
ax_ur_all[1].set_xscale('log')
# ax_u3_all[1].set_yscale('log')
ax_ur_all[1].set_xlabel(r'$r$')
ax_ur_all[1].set_ylabel(r'$u_r$')

ax_ur_all[1].set_xlim(1, 20)
# ax_u3_all[1].set_ylim(0, 20)

# plt.savefig('kz_analysis_result_r-t_rho_all.png', dpi=300)
plt.show()

# %%
# 将直角坐标(X,Y)转换为极坐标(R,Theta)
def cart2pol(x, y):
    r = np.sqrt(x**2 + y**2)
    theta = np.arctan2(y, x)
    return r, theta

# Set up polar plot
fig_contour_sigma_polar, ax_contour_sigma_polar = plt.subplots(subplot_kw={'projection': 'polar'})

# 对所有6组数据进行坐标转换并绘制
data_sets = [
    # a=0.5系列
    (X_a05e00, Y_a05e00, rav_sigma_a05e00, '#1f77b4', '-', r'$a=0.5, \eta=0.0$'),
    (X_a05ef5, Y_a05ef5, rav_sigma_a05ef5, '#ff7f0e', '--', r'$a=0.5, \eta=-0.5$'),
    (X_a05ez5, Y_a05ez5, rav_sigma_a05ez5, '#2ca02c', '--', r'$a=0.5, \eta=0.5$'),
    # a=0.9系列
    (X_a09e00, Y_a09e00, rav_sigma_a09e00, '#d62728', '-', r'$a=0.94, \eta=0.0$'),
    (X_a09ef1, Y_a09ef1, rav_sigma_a09ef1, '#9467bd', '--', r'$a=0.94, \eta=-0.1$'),
    (X_a09ez5, Y_a09ez5, rav_sigma_a09ez5, '#8c564b', '--', r'$a=0.94, \eta=0.5$')
]

# 绘制所有数据
for X, Y, sigma_data, color, style, label in data_sets:
    R, Theta = cart2pol(X, Y)
    cs = ax_contour_sigma_polar.contour(Theta, R, sigma_data,
                                      levels=[0], colors=color, 
                                      linestyles=style,
                                      linewidths=2)
    # 为图例添加一个空线条
    ax_contour_sigma_polar.plot([], [], color=color, linestyle=style, label=label)

# 添加一个半径为2的黑色圆盘在中心处
circle_radius = 2
theta = np.linspace(0, 2*np.pi, 100)
r = np.ones_like(theta) * circle_radius
ax_contour_sigma_polar.fill(theta, r, color='black', alpha=0.9, zorder=10) #置于最上层


angles = np.array([0, 15/180*np.pi, 30/180*np.pi, 45/180*np.pi, 60/180*np.pi, 75/180*np.pi, 90/180*np.pi])
ax_contour_sigma_polar.set_xticks(angles)
ax_contour_sigma_polar.set_xticklabels(['90°', '75°', '60°', '45°', '30°', '15°', '0°'])

ax_contour_sigma_polar.set_yticks([0, 5, 10, 15, 20])
ax_contour_sigma_polar.set_rlabel_position(0)
ax_contour_sigma_polar.set_xlim(0, 0.5*np.pi)
ax_contour_sigma_polar.set_ylim(0, 20)

# Enable grid
ax_contour_sigma_polar.grid(True)
ax_contour_sigma_polar.legend(loc='lower right', ncol=1)

# Display the plot
plt.show()

# %%
# 将角度限制在 [0, 2π] 范围内
angles = np.pi/2-np.array([0, np.pi/6, np.pi/4, np.pi/2, 3*np.pi/4, 5*np.pi/6, np.pi, 7*np.pi/6, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 11*np.pi/6])
angles[angles > 2*np.pi] -= 2*np.pi
angles[angles < 0] += 2*np.pi
print(angles)
# np.pi/2-np.array([0, np.pi/6, np.pi/4, np.pi/2, 3*np.pi/4, 5*np.pi/6, np.pi, 7*np.pi/6, 5*np.pi/4, 3*np.pi/2, 7*np.pi/4, 11*np.pi/6])
# Out:
# [1.57079633 1.04719755 0.78539816 0.         5.49778714 5.23598776
#  4.71238898 4.1887902  3.92699082 3.14159265 2.35619449 2.0943951 ]

# %%
X_a05e00 = ana_a05e00['rth'][0][:-1, :-1]
Y_a05e00 = ana_a05e00['rth'][1][:-1, :-1]
r_eh_a05e00 = 1.8660254037844388
rav_rho_a05e00 = np.log10(np.mean(ana_a05e00['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05e00 = np.log10(np.mean(ana_a05e00['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05e00 = np.log10(np.mean(ana_a05e00['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a05e00 = np.log10(np.mean(ana_a05e00['rtht/Theta'][t_start:t_end, :, :], axis=0))

X_a05ef5 = ana_a05ef5['rth'][0][:-1, :-1]
Y_a05ef5 = ana_a05ef5['rth'][1][:-1, :-1]
r_eh_a05ef5 = 1.6714615413885849
rav_rho_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a05ef5 = np.log10(np.mean(ana_a05ef5['rtht/Theta'][t_start:t_end, :, :], axis=0))

X_a05ez5 = ana_a05ez5['rth'][0][:-1, :-1]
Y_a05ez5 = ana_a05ez5['rth'][1][:-1, :-1]
r_eh_a05ez5 = 2
rav_rho_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a05ez5 = np.log10(np.mean(ana_a05ez5['rtht/Theta'][t_start:t_end, :, :], axis=0))

# %%
# 创建带有额外空间的图形
fig10 = plt.figure(figsize=(6.8, 8), dpi=300)
# 创建网格规范，减小colorbar的相对高度
gs10 = fig10.add_gridspec(4, 4, width_ratios=[1,1,1,0.05], hspace=0.12, wspace=0.1)

# 创建4个主要的子图
ax0_0 = fig10.add_subplot(gs10[0, 0])
ax1_0 = fig10.add_subplot(gs10[1, 0], sharex=ax0_0, sharey=ax0_0)
ax2_0 = fig10.add_subplot(gs10[2, 0], sharex=ax0_0, sharey=ax0_0)
ax3_0 = fig10.add_subplot(gs10[3, 0], sharex=ax0_0, sharey=ax0_0)
axs0 = [ax0_0, ax1_0, ax2_0, ax3_0] # a05ef5

ax0_1 = fig10.add_subplot(gs10[0, 1], sharex=ax0_0, sharey=ax0_0)
ax1_1 = fig10.add_subplot(gs10[1, 1], sharex=ax0_0, sharey=ax0_0)
ax2_1 = fig10.add_subplot(gs10[2, 1], sharex=ax0_0, sharey=ax0_0)
ax3_1 = fig10.add_subplot(gs10[3, 1], sharex=ax0_0, sharey=ax0_0)
axs1 = [ax0_1, ax1_1, ax2_1, ax3_1] # a05e00

ax0_2 = fig10.add_subplot(gs10[0, 2], sharex=ax0_0, sharey=ax0_0)
ax1_2 = fig10.add_subplot(gs10[1, 2], sharex=ax0_0, sharey=ax0_0)
ax2_2 = fig10.add_subplot(gs10[2, 2], sharex=ax0_0, sharey=ax0_0)
ax3_2 = fig10.add_subplot(gs10[3, 2], sharex=ax0_0, sharey=ax0_0)
axs2 = [ax0_2, ax1_2, ax2_2, ax3_2] # a05ez5


# 创建三个colorbar轴，每行一个
cax0 = fig10.add_subplot(gs10[0, -1])
cax1 = fig10.add_subplot(gs10[1, -1])
cax2 = fig10.add_subplot(gs10[2, -1])
cax3 = fig10.add_subplot(gs10[3, -1])

# 隐藏内部子图的刻度标签
plt.setp([ax.get_xticklabels() for ax in axs0[:-1]], visible=False)
plt.setp([ax.get_xticklabels() for ax in axs1[:-1]], visible=False)
plt.setp([ax.get_xticklabels() for ax in axs2[:-1]], visible=False)
plt.setp([ax.get_yticklabels() for ax in axs1[:]], visible=False)  
plt.setp([ax.get_yticklabels() for ax in axs2[:]], visible=False)  

rho_vmin = -4
rho_vmax = 0
sigma_vmin = -3
sigma_vmax = 3
inv_beta_vmin = -3
inv_beta_vmax = 3
Theta_vmin = -3
Theta_vmax = 0

x_lim_min = 0
x_lim_max = 50
y_lim_min = -25
y_lim_max = 25

xticks_list = [0,10,20,30,40,50]
ytick_list = [-20,-10,0,10,20]

# 密度图
im0_0 = axs0[0].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_rho_a05ef5, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs0[0].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_0 = axs0[0].contour(X_a05ef5, Y_a05ef5, rav_rho_a05ef5, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs0[0].set_xlim(x_lim_min, x_lim_max)
axs0[0].set_ylim(y_lim_min, y_lim_max)
axs0[0].set_yticks(ytick_list)
axs0[0].set_ylabel(r'$z~[M]$')
axs0[0].set_aspect('equal')
axs0[0].set_title(r'$a=0.5, \eta=-0.5$')

# sigma图
im1_0 = axs0[1].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_sigma_a05ef5, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs0[1].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_0 = axs0[1].contour(X_a05ef5, Y_a05ef5, rav_sigma_a05ef5, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs0[1].set_xlim(x_lim_min, x_lim_max)
axs0[1].set_ylim(y_lim_min, y_lim_max)
axs0[1].set_ylabel(r'$z~[M]$')
axs0[1].set_yticks(ytick_list)
axs0[1].set_aspect('equal')

# beta^-1图
im2_0 = axs0[2].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_inv_beta_a05ef5, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs0[2].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs0[2].set_xlim(x_lim_min, x_lim_max)
axs0[2].set_ylim(y_lim_min, y_lim_max)
axs0[2].set_ylabel(r'$z~[M]$')
axs0[2].set_yticks(ytick_list)
axs0[2].set_aspect('equal')
# Theta图   
im3_0 = axs0[3].pcolormesh(ana_a05ef5['rth'][0], ana_a05ef5['rth'][1], rav_Theta_a05ef5, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs0[3].fill(r_eh_a05ef5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ef5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs0[3].set_xlim(x_lim_min, x_lim_max)
axs0[3].set_ylim(y_lim_min, y_lim_max)
axs0[3].set_ylabel(r'$z~[M]$')
axs0[3].set_yticks(ytick_list)
axs0[3].set_xlabel(r'$x~[M]$')
axs0[3].set_xticks(xticks_list)
axs0[3].set_aspect('equal')



# 密度图
im0_1 = axs1[0].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_rho_a05e00, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs1[0].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_1 = axs1[0].contour(X_a05e00, Y_a05e00, rav_rho_a05e00, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs1[0].set_xlim(x_lim_min, x_lim_max)
axs1[0].set_ylim(y_lim_min, y_lim_max)
# axs1[0].set_ylabel(r'$z~[M]$')
axs1[0].set_aspect('equal')
axs1[0].set_title(r'$a=0.5, \eta=0.0$')
# sigma图
im1_1 = axs1[1].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_sigma_a05e00, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs1[1].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_1 = axs1[1].contour(X_a05e00, Y_a05e00, rav_sigma_a05e00, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs1[1].set_xlim(x_lim_min, x_lim_max)
axs1[1].set_ylim(y_lim_min, y_lim_max)
# axs1[1].set_xlabel(r'$x~[M]$')
axs1[1].set_aspect('equal')

# beta^-1图
im2_1 = axs1[2].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_inv_beta_a05e00, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs1[2].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs1[2].set_xlim(x_lim_min, x_lim_max)
axs1[2].set_ylim(y_lim_min, y_lim_max)
# axs1[2].set_yticklabels([])
axs1[2].set_aspect('equal')
# Theta图   
im3_1 = axs1[3].pcolormesh(ana_a05e00['rth'][0], ana_a05e00['rth'][1], rav_Theta_a05e00, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs1[3].fill(r_eh_a05e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs1[3].set_xlim(x_lim_min, x_lim_max)
axs1[3].set_ylim(y_lim_min, y_lim_max)
axs1[3].set_xlabel(r'$x~[M]$')
axs1[3].set_xticks(xticks_list)
axs1[3].set_aspect('equal')


# 密度图
im0_2 = axs2[0].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_rho_a05ez5, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs2[0].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_2 = axs2[0].contour(X_a05ez5, Y_a05ez5, rav_rho_a05ez5, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs2[0].set_xlim(x_lim_min, x_lim_max)
axs2[0].set_ylim(y_lim_min, y_lim_max)
# axs2[0].set_ylabel(r'$z~[M]$')
axs2[0].set_aspect('equal')
axs2[0].set_title(r'$a=0.5, \eta=0.5$')
# sigma图
im1_2 = axs2[1].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_sigma_a05ez5, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs2[1].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_2 = axs2[1].contour(X_a05ez5, Y_a05ez5, rav_sigma_a05ez5, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs2[1].set_xlim(x_lim_min, x_lim_max)
axs2[1].set_ylim(y_lim_min, y_lim_max)
# axs2[1].set_xlabel(r'$x~[M]$')
# axs2[1].set_yticklabels([])
axs2[1].set_aspect('equal')

# beta^-1图
im2_2 = axs2[2].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_inv_beta_a05ez5, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs2[2].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[2].set_xlim(x_lim_min, x_lim_max)
axs2[2].set_ylim(y_lim_min, y_lim_max)
# axs2[2].set_yticklabels([])
axs2[2].set_aspect('equal')
# Theta图   
im3_2 = axs2[3].pcolormesh(ana_a05ez5['rth'][0], ana_a05ez5['rth'][1], rav_Theta_a05ez5, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs2[3].fill(r_eh_a05ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a05ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[3].set_xlim(x_lim_min, x_lim_max)
axs2[3].set_ylim(y_lim_min, y_lim_max)
axs2[3].set_xlabel(r'$x~[M]$')
axs2[3].set_xticks(xticks_list)
axs2[3].set_aspect('equal')


cbar_rho = fig10.colorbar(im0_0, cax=cax0, label=r'$\log_{10}(\rho)$')
cbar_rho.set_ticks([-4,-3,-2,-1,0])
cbar_sigma = fig10.colorbar(im1_0, cax=cax1, label=r'$\log_{10}(\sigma)$')
cbar_sigma.set_ticks([-3,-2,-1,0,1,2,3])
cbar_inv_beta = fig10.colorbar(im2_0, cax=cax2, label=r'$\log_{10}(\beta^{-1})$')
cbar_inv_beta.set_ticks([-3,-2,-1,0,1,2,3])
cbar_Theta = fig10.colorbar(im3_0, cax=cax3, label=r'$\log_{10}(p_g/\rho)$')
cbar_Theta.set_ticks([-3,-2,-1,0])


plt.savefig("kz_analysis_result_3d_a05.png", dpi=300, format="png", bbox_inches="tight")
plt.savefig("kz_analysis_result_3d_a05.eps", dpi=300, format="eps", bbox_inches="tight")
plt.show()
plt.close()

# %%
X_a09ef1 = ana_a09ef1['rth'][0][:-1, :-1]
Y_a09ef1 = ana_a09ef1['rth'][1][:-1, :-1]
r_eh_a09ef1 = 1.1930710966073588
rav_rho_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a09ef1 = np.log10(np.mean(ana_a09ef1['rtht/Theta'][t_start:t_end, :, :], axis=0))

X_a09e00 = ana_a09e00['rth'][0][:-1, :-1]
Y_a09e00 = ana_a09e00['rth'][1][:-1, :-1]
r_eh_a09e00 = 1.3479852726768762
rav_rho_a09e00 = np.log10(np.mean(ana_a09e00['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09e00 = np.log10(np.mean(ana_a09e00['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09e00 = np.log10(np.mean(ana_a09e00['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a09e00 = np.log10(np.mean(ana_a09e00['rtht/Theta'][t_start:t_end, :, :], axis=0))

X_a09ez5 = ana_a09ez5['rth'][0][:-1, :-1]
Y_a09ez5 = ana_a09ez5['rth'][1][:-1, :-1]
r_eh_a09ez5 = 1.651093913198195
rav_rho_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/rho'][t_start:t_end, :, :], axis=0))
rav_sigma_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/sigma'][t_start:t_end, :, :], axis=0))
rav_inv_beta_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/inv_beta'][t_start:t_end, :, :], axis=0))
rav_Theta_a09ez5 = np.log10(np.mean(ana_a09ez5['rtht/Theta'][t_start:t_end, :, :], axis=0))

# %%
# 创建带有额外空间的图形
fig11 = plt.figure(figsize=(6.8, 8), dpi=300)
# 创建网格规范，减小colorbar的相对高度
gs11 = fig11.add_gridspec(4, 4, width_ratios=[1,1,1,0.05], hspace=0.12, wspace=0.1)

# 创建4个主要的子图
ax0_0 = fig11.add_subplot(gs11[0, 0])
ax1_0 = fig11.add_subplot(gs11[1, 0], sharex=ax0_0, sharey=ax0_0)
ax2_0 = fig11.add_subplot(gs11[2, 0], sharex=ax0_0, sharey=ax0_0)
ax3_0 = fig11.add_subplot(gs11[3, 0], sharex=ax0_0, sharey=ax0_0)
axs0 = [ax0_0, ax1_0, ax2_0, ax3_0] # a05ef5

ax0_1 = fig11.add_subplot(gs11[0, 1], sharex=ax0_0, sharey=ax0_0)
ax1_1 = fig11.add_subplot(gs11[1, 1], sharex=ax0_0, sharey=ax0_0)
ax2_1 = fig11.add_subplot(gs11[2, 1], sharex=ax0_0, sharey=ax0_0)
ax3_1 = fig11.add_subplot(gs11[3, 1], sharex=ax0_0, sharey=ax0_0)
axs1 = [ax0_1, ax1_1, ax2_1, ax3_1] # a05e00

ax0_2 = fig11.add_subplot(gs11[0, 2], sharex=ax0_0, sharey=ax0_0)
ax1_2 = fig11.add_subplot(gs11[1, 2], sharex=ax0_0, sharey=ax0_0)
ax2_2 = fig11.add_subplot(gs11[2, 2], sharex=ax0_0, sharey=ax0_0)
ax3_2 = fig11.add_subplot(gs11[3, 2], sharex=ax0_0, sharey=ax0_0)
axs2 = [ax0_2, ax1_2, ax2_2, ax3_2] # a05ez5


# 创建三个colorbar轴，每行一个
cax0 = fig11.add_subplot(gs11[0, -1])
cax1 = fig11.add_subplot(gs11[1, -1])
cax2 = fig11.add_subplot(gs11[2, -1])
cax3 = fig11.add_subplot(gs11[3, -1])

# 隐藏内部子图的刻度标签
plt.setp([ax.get_xticklabels() for ax in axs0[:-1]], visible=False)
plt.setp([ax.get_xticklabels() for ax in axs1[:-1]], visible=False)
plt.setp([ax.get_xticklabels() for ax in axs2[:-1]], visible=False)
plt.setp([ax.get_yticklabels() for ax in axs1[:]], visible=False)  
plt.setp([ax.get_yticklabels() for ax in axs2[:]], visible=False)  

rho_vmin = -4
rho_vmax = 0
sigma_vmin = -3
sigma_vmax = 3
inv_beta_vmin = -3
inv_beta_vmax = 3
Theta_vmin = -3
Theta_vmax = 0

x_lim_min = 0
x_lim_max = 50
y_lim_min = -25
y_lim_max = 25

xticks_list = [0,10,20,30,40,50]
ytick_list = [-20,-10,0,10,20]

# 密度图
im0_0 = axs0[0].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_rho_a09ef1, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs0[0].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_0 = axs0[0].contour(X_a09ef1, Y_a09ef1, rav_rho_a09ef1, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs0[0].set_xlim(x_lim_min, x_lim_max)
axs0[0].set_ylim(y_lim_min, y_lim_max)
axs0[0].set_yticks(ytick_list)
axs0[0].set_ylabel(r'$z~[M]$')
axs0[0].set_aspect('equal')
axs0[0].set_title(r'$a=0.94, \eta=-0.1$')

# sigma图
im1_0 = axs0[1].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_sigma_a09ef1, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs0[1].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_0 = axs0[1].contour(X_a09ef1, Y_a09ef1, rav_sigma_a09ef1, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs0[1].set_xlim(x_lim_min, x_lim_max)
axs0[1].set_ylim(y_lim_min, y_lim_max)
axs0[1].set_ylabel(r'$z~[M]$')
axs0[1].set_yticks(ytick_list)
axs0[1].set_aspect('equal')

# beta^-1图
im2_0 = axs0[2].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_inv_beta_a09ef1, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs0[2].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs0[2].set_xlim(x_lim_min, x_lim_max)
axs0[2].set_ylim(y_lim_min, y_lim_max)
axs0[2].set_ylabel(r'$z~[M]$')
axs0[2].set_yticks(ytick_list)
axs0[2].set_aspect('equal')
# Theta图   
im3_0 = axs0[3].pcolormesh(ana_a09ef1['rth'][0], ana_a09ef1['rth'][1], rav_Theta_a09ef1, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs0[3].fill(r_eh_a09ef1*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ef1*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs0[3].set_xlim(x_lim_min, x_lim_max)
axs0[3].set_ylim(y_lim_min, y_lim_max)
axs0[3].set_ylabel(r'$z~[M]$')
axs0[3].set_yticks(ytick_list)
axs0[3].set_xlabel(r'$x~[M]$')
axs0[3].set_xticks(xticks_list)
axs0[3].set_aspect('equal')



# 密度图
im0_1 = axs1[0].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_rho_a09e00, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs1[0].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_1 = axs1[0].contour(X_a09e00, Y_a09e00, rav_rho_a09e00, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs1[0].set_xlim(x_lim_min, x_lim_max)
axs1[0].set_ylim(y_lim_min, y_lim_max)
# axs1[0].set_ylabel(r'$z~[M]$')
axs1[0].set_aspect('equal')
axs1[0].set_title(r'$a=0.94, \eta=0.0$')
# sigma图
im1_1 = axs1[1].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_sigma_a09e00, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs1[1].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_1 = axs1[1].contour(X_a09e00, Y_a09e00, rav_sigma_a09e00, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs1[1].set_xlim(x_lim_min, x_lim_max)
axs1[1].set_ylim(y_lim_min, y_lim_max)
# axs1[1].set_xlabel(r'$x~[M]$')
axs1[1].set_aspect('equal')

# beta^-1图
im2_1 = axs1[2].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_inv_beta_a09e00, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs1[2].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs1[2].set_xlim(x_lim_min, x_lim_max)
axs1[2].set_ylim(y_lim_min, y_lim_max)
# axs1[2].set_yticklabels([])
axs1[2].set_aspect('equal')
# Theta图   
im3_1 = axs1[3].pcolormesh(ana_a09e00['rth'][0], ana_a09e00['rth'][1], rav_Theta_a09e00, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs1[3].fill(r_eh_a09e00*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09e00*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs1[3].set_xlim(x_lim_min, x_lim_max)
axs1[3].set_ylim(y_lim_min, y_lim_max)
axs1[3].set_xlabel(r'$x~[M]$')
axs1[3].set_xticks(xticks_list)
axs1[3].set_aspect('equal')


# 密度图
im0_2 = axs2[0].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_rho_a09ez5, norm=Normalize(vmin=rho_vmin, vmax=rho_vmax), cmap='jet')
axs2[0].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs0_2 = axs2[0].contour(X_a09ez5, Y_a09ez5, rav_rho_a09ez5, levels=contour_levels_rho, colors='black', linewidths=0.6)
axs2[0].set_xlim(x_lim_min, x_lim_max)
axs2[0].set_ylim(y_lim_min, y_lim_max)
# axs2[0].set_ylabel(r'$z~[M]$')
axs2[0].set_aspect('equal')
axs2[0].set_title(r'$a=0.94, \eta=0.5$')
# sigma图
im1_2 = axs2[1].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_sigma_a09ez5, norm=Normalize(vmin=sigma_vmin, vmax=sigma_vmax), cmap='RdYlGn')
axs2[1].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
cs1_2 = axs2[1].contour(X_a09ez5, Y_a09ez5, rav_sigma_a09ez5, levels=contour_levels_sigma, colors='black', linewidths=0.6)
axs2[1].set_xlim(x_lim_min, x_lim_max)
axs2[1].set_ylim(y_lim_min, y_lim_max)
# axs2[1].set_xlabel(r'$x~[M]$')
# axs2[1].set_yticklabels([])
axs2[1].set_aspect('equal')

# beta^-1图
im2_2 = axs2[2].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_inv_beta_a09ez5, norm=Normalize(vmin=inv_beta_vmin, vmax=inv_beta_vmax), cmap='viridis')
axs2[2].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[2].set_xlim(x_lim_min, x_lim_max)
axs2[2].set_ylim(y_lim_min, y_lim_max)
# axs2[2].set_yticklabels([])
axs2[2].set_aspect('equal')
# Theta图   
im3_2 = axs2[3].pcolormesh(ana_a09ez5['rth'][0], ana_a09ez5['rth'][1], rav_Theta_a09ez5, norm=Normalize(vmin=Theta_vmin, vmax=Theta_vmax), cmap='afmhot')
axs2[3].fill(r_eh_a09ez5*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh_a09ez5*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[3].set_xlim(x_lim_min, x_lim_max)
axs2[3].set_ylim(y_lim_min, y_lim_max)
axs2[3].set_xlabel(r'$x~[M]$')
axs2[3].set_xticks(xticks_list)
axs2[3].set_aspect('equal')


cbar_rho = fig11.colorbar(im0_0, cax=cax0, label=r'$\log_{10}(\rho)$')
cbar_rho.set_ticks([-4,-3,-2,-1,0])
cbar_sigma = fig11.colorbar(im1_0, cax=cax1, label=r'$\log_{10}(\sigma)$')
cbar_sigma.set_ticks([-3,-2,-1,0,1,2,3])
cbar_inv_beta = fig11.colorbar(im2_0, cax=cax2, label=r'$\log_{10}(\beta^{-1})$')
cbar_inv_beta.set_ticks([-3,-2,-1,0,1,2,3])
cbar_Theta = fig11.colorbar(im3_0, cax=cax3, label=r'$\log_{10}(p_g/\rho)$')
cbar_Theta.set_ticks([-3,-2,-1,0])
# plt.tight_layout()
plt.savefig("kz_analysis_result_3d_a094.png", dpi=300, format="png", bbox_inches="tight")
plt.savefig("kz_analysis_result_3d_a094.eps", dpi=300, format="eps", bbox_inches="tight")
plt.show()
plt.close()
