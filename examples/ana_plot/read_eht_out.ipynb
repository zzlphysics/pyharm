# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pyharm.ana_results as an

# %%
ana_file = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_05000_192-96-96/eht_out.h5"

# %%
ana = an.load_results(ana_file)

# %%
# r, th = ana.get_ivar('rth')
mdot = ana.get_result('t', 'mdot')
phi_b = ana.get_result('t', 'phi_b')
edot = ana.get_result('t', 'edot')
ldot = ana.get_result('t', 'ldot')
eff = ana.get_result('t', 'eff')

figs, axs = plt.subplots(5, 1, figsize=(6.4, 10))
axs[0].plot(mdot[0], mdot[1])
axs[0].set_ylabel(r'$\dot{M}$')
axs[1].plot(phi_b[0], phi_b[1])
axs[1].set_ylabel(r'$\phi_b$')
axs[2].plot(edot[0], edot[1])
axs[2].set_ylabel(r'$\dot{E}$')
axs[3].plot(ldot[0], ldot[1])
axs[3].set_ylabel(r'$\dot{L}$')
axs[4].plot(eff[0], eff[1])
axs[4].set_ylabel(r'$\left|\dot{E} - \dot{M}\right| / \langle\dot{E}\rangle$')
plt.show()

# %%
rav = ana.get_ivar('r')
print(rav)
# Out:
# [array([  1.57670993,   1.63074086,   1.68662333,   1.74442078,
#          1.80419885,   1.8660254 ,   1.92997064,   1.99610716,
#          2.06451005,   2.13525699,   2.20842829,   2.28410703,
#          2.36237915,   2.44333351,   2.52706202,   2.61365975,
#          2.70322503,   2.79585955,   2.89166847,   2.99076059,
#          3.09324842,   3.19924831,   3.30888063,   3.42226983,
#          3.53954468,   3.66083832,   3.78628847,   3.91603756,
#          4.05023291,   4.18902689,   4.33257708,   4.48104647,
#          4.63460364,   4.79342292,   4.95768464,   5.12757531,
#          5.30328782,   5.48502166,   5.6729832 ,   5.86738582,
#          6.06845026,   6.27640481,   6.49148558,   6.71393676,
#          6.94401094,   7.18196933,   7.42808211,   7.68262873,
#          7.94589818,   8.21818939,   8.49981152,   8.79108431,
#          9.09233849,   9.40391608,   9.72617087,  10.05946872,
#         10.40418808,  10.76072033,  11.12947028,  11.51085661,
#         11.90531235,  12.31328534,  12.73523882,  13.17165186,
#         13.62301997,  14.08985563,  14.57268888,  15.07206793,
#         15.58855978,  16.12275085,  16.67524765,  17.2466775 ,
#         17.83768918,  18.44895375,  19.08116522,  19.7350414 ,
#         20.41132471,  21.11078299,  21.83421042,  22.58242836,
#         23.35628635,  24.15666301,  24.9844671 ,  25.84063851,
#         26.72614932,  27.64200495,  28.58924525,  29.56894572,
#         30.58221871,  31.6302147 ,  32.71412356,  33.83517597,
#         34.99464477,  36.19384642,  37.43414248,  38.7169412 ,
#         40.04369905,  41.41592244,  42.83516937,  44.30305127,
#         45.82123477,  47.3914436 ,  49.01546058,  50.69512961,
#         52.43235779,  54.22911756,  56.08744896,  58.00946193,
#         59.99733873,  62.05333638,  64.17978926,  66.37911175,
#         68.65380094,  71.00643951,  73.43969866,  75.95634108,
#         78.55922418,  81.25130326,  84.0356349 ,  86.91538043,
#         89.89380951,  92.97430383,  96.16036099,  99.45559842,
#        102.86375754, 106.38870795, 110.03445188, 113.80512871,
#        117.70501964, 121.73855262, 125.91030729, 130.22502027,
#        134.68759047, 139.30308469, 144.07674334, 149.01398643,
#        154.12041969, 159.40184097, 164.86424676, 170.51383909,
#        176.35703247, 182.40046127, 188.65098718, 195.11570703,
#        201.80196086, 208.71734021, 215.86969681, 223.26715142,
#        230.91810309, 238.8312387 , 247.01554282, 255.48030787,
#        264.23514474, 273.28999365, 282.65513546, 292.34120333,
#        302.3591948 , 312.72048428, 323.43683595, 334.52041715,
#        345.98381214, 357.84003644, 370.10255159, 382.78528041,
#        395.90262285, 409.46947232, 423.50123259, 438.01383529,
#        453.023758  , 468.54804295, 484.60431639, 501.21080858,
#        518.38637449, 536.15051522, 554.52340015, 573.52588981,
#        593.17955959, 613.50672422, 634.53046313, 656.27464662,
#        678.763963  , 702.0239466 , 726.08100673, 750.96245776,
#        776.69655002, 803.31250194, 830.84053324, 859.31189917,
#        888.75892606, 919.21504802, 950.71484485, 983.29408137])]

# %%
rav_mdot = ana.get_result('r', 'mdot')
print(rav_mdot[0].shape, rav_mdot[1].shape)
# plt.plot(rav_mdot[0], rav_mdot[1])
# plt.show()
# Out:
# (192,) (1581,)

# %%
print(ana['t'].shape)
print(ana['r'].shape)
print(ana['rth'][0].shape, ana['rth'][1].shape)
print(ana['rtht/rho'].shape)
# print(ana['t/phi_b'].shape)
# print(ana['t/mdot'].shape)
# print(ana['r/phi_b'].shape)
# Out:
# (1581,)
# (192,)
# (193, 97) (193, 97)
# (1581, 192, 96)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

X = ana['rth'][0][:-1, :-1]
Y = ana['rth'][1][:-1, :-1]


r_eh = 1.8660254037844386

rav_rho = np.log10(np.mean(ana['rtht/rho'][500:1000, :, :], axis=0))
rav_sigma = np.log10(np.mean(ana['rtht/sigma'][500:1000, :, :], axis=0))
rav_inv_beta = np.log10(np.mean(ana['rtht/inv_beta'][500:1000, :, :], axis=0))

# 创建带有额外空间的图形
fig2 = plt.figure(figsize=(9, 6))
# 创建网格规范，减小colorbar的相对高度
gs = fig2.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# 创建三个主要的子图
ax1 = fig2.add_subplot(gs[1, 0])
ax2 = fig2.add_subplot(gs[1, 1])
ax3 = fig2.add_subplot(gs[1, 2])
axs2 = [ax1, ax2, ax3]

# 密度图
im0 = axs2[0].pcolormesh(ana['rth'][0], ana['rth'][1], rav_rho, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet')
axs2[0].fill(r_eh*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# Add contour line where log10(rho) = -2 (rho = 0.01)
contour_levels_rho = [-2]
cs0 = axs2[0].contour(X, Y, rav_rho, 
                      levels=contour_levels_rho, colors='black')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='black')

axs2[0].set_xlim(0, 50)
axs2[0].set_ylim(-50, 50)
axs2[0].set_aspect('equal')
cax0 = fig2.add_subplot(gs[0, 0])
cbar0 = plt.colorbar(im0, cax=cax0, orientation='horizontal')
cbar0.ax.xaxis.set_ticks_position('top')
cbar0.ax.xaxis.set_label_position('top')
cbar0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')


# sigma图
im1 = axs2[1].pcolormesh(ana['rth'][0], ana['rth'][1], rav_sigma,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma')
axs2[1].fill(r_eh*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
# 增加sigma=1的等值线
contour_levels_sigma = [0]
cs1 = axs2[1].contour(X, Y, rav_sigma, 
                      levels=contour_levels_sigma, colors='black')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='black')

axs2[1].set_xlim(0, 50)
axs2[1].set_ylim(-50, 50)
axs2[1].set_aspect('equal')
cax1 = fig2.add_subplot(gs[0, 1])
cbar1 = plt.colorbar(im1, cax=cax1, orientation='horizontal')
cbar1.ax.xaxis.set_ticks_position('top')
cbar1.ax.xaxis.set_label_position('top')
cbar1.set_ticks([-2, -1, 0, 1, 2, 3])
cbar1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# beta^-1图
im2 = axs2[2].pcolormesh(ana['rth'][0], ana['rth'][1], rav_inv_beta,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis')
axs2[2].fill(r_eh*np.cos(np.linspace(0, 2*np.pi, 100)), r_eh*np.sin(np.linspace(0, 2*np.pi, 100)), color='black')
axs2[2].set_xlim(0, 50)
axs2[2].set_ylim(-50, 50)
axs2[2].set_aspect('equal')
cax2 = fig2.add_subplot(gs[0, 2])
cbar2 = plt.colorbar(im2, cax=cax2, orientation='horizontal')
cbar2.ax.xaxis.set_ticks_position('top')
cbar2.ax.xaxis.set_label_position('top')
cbar2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2174578/1354010147.py:83: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import numpy as np

# Assuming 'ana' is your data dictionary and the data has been loaded appropriately

r_eh = 1.8660254037844386

# Averaging over the time dimension
rav_rho = np.log10(np.mean(ana['rtht/rho'][500:1000, :, :], axis=0))
rav_sigma = np.log10(np.mean(ana['rtht/sigma'][500:1000, :, :], axis=0))
rav_inv_beta = np.log10(np.mean(ana['rtht/inv_beta'][500:1000, :, :], axis=0))

# Adjust the grid arrays for contour plots
X = ana['rth'][0][:-1, :-1]
Y = ana['rth'][1][:-1, :-1]

# Create the figure and gridspec
fig2 = plt.figure(figsize=(9, 6))
gs = fig2.add_gridspec(2, 3, height_ratios=[0.03, 1], hspace=0.2)

# Create the subplots
ax1 = fig2.add_subplot(gs[1, 0])
ax2 = fig2.add_subplot(gs[1, 1])
ax3 = fig2.add_subplot(gs[1, 2])
axs2 = [ax1, ax2, ax3]

# Density plot
im0 = axs2[0].pcolormesh(ana['rth'][0], ana['rth'][1], rav_rho, 
                         norm=Normalize(vmin=-5, vmax=0),
                         cmap='jet', shading='auto')
axs2[0].fill(r_eh * np.cos(np.linspace(0, 2 * np.pi, 100)), 
             r_eh * np.sin(np.linspace(0, 2 * np.pi, 100)), color='black')

# Add contour line where log10(rho) = -2 (rho = 0.01)
contour_levels_rho = [-2]
cs0 = axs2[0].contour(X, Y, rav_rho, 
                      levels=contour_levels_rho, colors='white')
# axs2[0].clabel(cs0, fmt='%2.1f', colors='white')

axs2[0].set_xlim(0, 50)
axs2[0].set_ylim(-50, 50)
axs2[0].set_aspect('equal')
cax0 = fig2.add_subplot(gs[0, 0])
cbar0 = plt.colorbar(im0, cax=cax0, orientation='horizontal')
cbar0.ax.xaxis.set_ticks_position('top')
cbar0.ax.xaxis.set_label_position('top')
cbar0.set_ticks([-5, -4, -3, -2, -1, 0])
cbar0.set_label(r'$log_{10}\langle\rho\rangle_{t,\phi}$')

# Sigma plot
im1 = axs2[1].pcolormesh(ana['rth'][0], ana['rth'][1], rav_sigma,
                         norm=Normalize(vmin=-2, vmax=3),
                         cmap='plasma', shading='auto')
axs2[1].fill(r_eh * np.cos(np.linspace(0, 2 * np.pi, 100)), 
             r_eh * np.sin(np.linspace(0, 2 * np.pi, 100)), color='black')

# Add contour line where log10(sigma) = 0 (sigma = 1)
contour_levels_sigma = [0]
cs1 = axs2[1].contour(X, Y, rav_sigma, 
                      levels=contour_levels_sigma, colors='white')
# axs2[1].clabel(cs1, fmt='%2.1f', colors='white')

axs2[1].set_xlim(0, 50)
axs2[1].set_ylim(-50, 50)
axs2[1].set_aspect('equal')
cax1 = fig2.add_subplot(gs[0, 1])
cbar1 = plt.colorbar(im1, cax=cax1, orientation='horizontal')
cbar1.ax.xaxis.set_ticks_position('top')
cbar1.ax.xaxis.set_label_position('top')
cbar1.set_ticks([-2, -1, 0, 1, 2, 3])
cbar1.set_label(r'$log_{10}\langle\sigma\rangle_{t,\phi}$')

# Beta^-1 plot
im2 = axs2[2].pcolormesh(ana['rth'][0], ana['rth'][1], rav_inv_beta,
                         norm=Normalize(vmin=-3, vmax=3),
                         cmap='viridis', shading='auto')
axs2[2].fill(r_eh * np.cos(np.linspace(0, 2 * np.pi, 100)), 
             r_eh * np.sin(np.linspace(0, 2 * np.pi, 100)), color='black')

# Optionally, add contour lines for rav_inv_beta if desired
# For example, contour where log10(beta^-1) = 0 (beta^-1 = 1)
# contour_levels_inv_beta = [0]
# cs2 = axs2[2].contour(X, Y, rav_inv_beta, 
#                       levels=contour_levels_inv_beta, colors='white')
# axs2[2].clabel(cs2, fmt='%2.1f', colors='white')

axs2[2].set_xlim(0, 50)
axs2[2].set_ylim(-50, 50)
axs2[2].set_aspect('equal')
cax2 = fig2.add_subplot(gs[0, 2])
cbar2 = plt.colorbar(im2, cax=cax2, orientation='horizontal')
cbar2.ax.xaxis.set_ticks_position('top')
cbar2.ax.xaxis.set_label_position('top')
cbar2.set_ticks([-3, -2, -1, 0, 1, 2, 3])
cbar2.set_label(r'$log_{10}\langle\beta^{-1}\rangle_{t,\phi}$')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2174578/3378242256.py:98: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import h5py
import numpy as np

def print_group_structure(group, indent=""):
    for key in group.keys():
        print(f"{indent}{key}")
        if isinstance(group[key], h5py.Group):
            print_group_structure(group[key], indent + "  ")

def print_datasets(group, path=""):
    for key, item in group.items():
        new_path = f"{path}/{key}"
        if isinstance(item, h5py.Dataset):
            print(f"{new_path}: shape {item.shape}, dtype {item.dtype}")
        elif isinstance(item, h5py.Group):
            print_datasets(item, new_path)

def print_attributes(group, path=""):
    for key, item in group.items():
        new_path = f"{path}/{key}"
        if isinstance(item, h5py.Dataset) or isinstance(item, h5py.Group):
            if len(item.attrs) > 0:
                print(f"\n{new_path} 属性:")
                for attr_name, attr_value in item.attrs.items():
                    print(f"  {attr_name}: {attr_value}")
        if isinstance(item, h5py.Group):
            print_attributes(item, new_path)


# 在 explore_hdf5 函数中添加对 check_version 的调用
def explore_hdf5(file_path):
    with h5py.File(file_path, 'r') as f:
        print(f"文件: {file_path}")
        
        print("\n群组结构:")
        print_group_structure(f)
        
        print("\n数据集:")
        print_datasets(f)
        
        print("\n属性:")
        print_attributes(f)

# %%
explore_hdf5(ana_file)
# Out:
# 文件: /home/zhangzelin/projects/kharma/output/20241018_hip_mad_05000_192-96-96/eht_out.h5
#
# 群组结构:
# avg
#   end
#   start
# coord
#   t
# diag
#   FFlags
#   FOFCFlags
#   MaxDivB
#   PFlags
#   Phi_0
#   Phi_5M
#   Phi_EH
#   dt
#   time
# extras
#   pyharm_params
# header
#   a
#   base
#   cfl
#   connection_average_points
#   coordinates
#   correct_connections
#   cour
#   derefine_tol
#   domain_intersects_eh
#   dt
#   dt_min
#   dump_cadence
#   dx1
#   dx2
#   dx3
#   electrons
#   emhd
#   ext_g
#   fname_fill
#   gam
#   gam_e
#   gam_p
#   gamma
#   geom
#     dx1
#     dx2
#     dx3
#     mks
#       a
#       hslope
#       r_eh
#       r_in
#       r_out
#     n_dim
#     startx1
#     startx2
#     startx3
#   gridfile
#   hslope
#   ideal_guess
#   implicit
#   integrator
#   ix1_bc
#   ix2_bc
#   ix3_bc
#   kappa
#   max_dt_increase
#   metric
#   multigrid
#   n1
#   n1tot
#   n2
#   n2tot
#   n3
#   n3tot
#   n_dump
#   n_prim
#   n_prims_passive
#   n_step
#   ncycle
#   ncycle_out
#   ncycle_out_mesh
#   ng_file
#   nghost
#   nlim
#   num_blocks
#   num_threads
#   nx1
#   nx2
#   nx3
#   on
#   ox1_bc
#   ox2_bc
#   ox3_bc
#   pack_size
#   prim_names
#   r_eh
#   r_in
#   r_out
#   reconstruction
#   recv_bdry_buf_timeout_sec
#   refine_tol
#   refinement
#   refinement_in_one_min_nbufs
#   restart_x1max
#   restart_x1min
#   rhor
#   rin
#   rmax
#   spherical
#   start_dt_light
#   start_time
#   startx1
#   startx2
#   startx3
#   sync_utop_seed
#   t
#   tf
#   tilt
#   tlim
#   transform
#   use_dt_light
#   use_dt_light_phase_speed
#   version
#   x1max
#   x1min
#   x1rat
#   x2max
#   x2min
#   x2rat
#   x3max
#   x3min
#   x3rat
# htht
#   omega
# rt
#   FE_all
#   FE_disk
#   FL_all
#   FL_disk
#   FM_all
#   FM_disk
#   JE0
#   JE1
#   JE2
#   Pg_disk
#   Pg_notdisk
#   Ptot_disk
#   Ptot_notdisk
#   b_disk
#   b_notdisk
#   inv_beta_disk
#   inv_beta_notdisk
#   outEflow
#   outflow
#   rho_disk
#   rho_notdisk
#   u^3_disk
#   u^3_notdisk
#   u^r_disk
#   u^r_notdisk
#   u_3_disk
#   u_3_notdisk
# rtht
#   Theta
#   inv_beta
#   rho
#   sigma
# t
#   Edot
#   Ldot
#   Mdot
#   Phi_b
#   Phi_b_5
#   Phi_b_lower
#   Phi_b_lower_5
#   Phi_b_upper
#   Phi_b_upper_5
#   is_avg
# tht
#   inv_beta_40
#   sigma_40
#
# 数据集:
# /avg/end: shape (), dtype float64
# /avg/start: shape (), dtype float64
# /coord/t: shape (1581,), dtype float32
# /diag/FFlags: shape (31606,), dtype float64
# /diag/FOFCFlags: shape (31606,), dtype float64
# /diag/MaxDivB: shape (31606,), dtype float64
# /diag/PFlags: shape (31606,), dtype float64
# /diag/Phi_0: shape (31606,), dtype float64
# /diag/Phi_5M: shape (31606,), dtype float64
# /diag/Phi_EH: shape (31606,), dtype float64
# /diag/dt: shape (31606,), dtype float64
# /diag/time: shape (31606,), dtype float64
# /header/a: shape (), dtype float64
# /header/base: shape (), dtype |S20
# /header/cfl: shape (), dtype float64
# /header/connection_average_points: shape (), dtype int64
# /header/coordinates: shape (), dtype |S20
# /header/correct_connections: shape (), dtype int64
# /header/cour: shape (), dtype float64
# /header/derefine_tol: shape (), dtype float64
# /header/domain_intersects_eh: shape (), dtype int64
# /header/dt: shape (), dtype float64
# /header/dt_min: shape (), dtype float64
# /header/dump_cadence: shape (), dtype float64
# /header/dx1: shape (), dtype float64
# /header/dx2: shape (), dtype float64
# /header/dx3: shape (), dtype float64
# /header/electrons: shape (), dtype bool
# /header/emhd: shape (), dtype int64
# /header/ext_g: shape (), dtype int64
# /header/fname_fill: shape (), dtype |S20
# /header/gam: shape (), dtype float64
# /header/gam_e: shape (), dtype float64
# /header/gam_p: shape (), dtype float64
# /header/gamma: shape (), dtype float64
# /header/geom/dx1: shape (), dtype float64
# /header/geom/dx2: shape (), dtype float64
# /header/geom/dx3: shape (), dtype float64
# /header/geom/mks/a: shape (), dtype float64
# /header/geom/mks/hslope: shape (), dtype float64
# /header/geom/mks/r_eh: shape (), dtype float64
# /header/geom/mks/r_in: shape (), dtype float64
# /header/geom/mks/r_out: shape (), dtype int64
# /header/geom/n_dim: shape (), dtype int64
# /header/geom/startx1: shape (), dtype float64
# /header/geom/startx2: shape (), dtype float64
# /header/geom/startx3: shape (), dtype float64
# /header/gridfile: shape (), dtype |S20
# /header/hslope: shape (), dtype float64
# /header/ideal_guess: shape (), dtype int64
# /header/implicit: shape (), dtype int64
# /header/integrator: shape (), dtype |S20
# /header/ix1_bc: shape (), dtype |S20
# /header/ix2_bc: shape (), dtype |S20
# /header/ix3_bc: shape (), dtype |S20
# /header/kappa: shape (), dtype float64
# /header/max_dt_increase: shape (), dtype float64
# /header/metric: shape (), dtype |S20
# /header/multigrid: shape (), dtype bool
# /header/n1: shape (), dtype int64
# /header/n1tot: shape (), dtype int64
# /header/n2: shape (), dtype int64
# /header/n2tot: shape (), dtype int64
# /header/n3: shape (), dtype int64
# /header/n3tot: shape (), dtype int64
# /header/n_dump: shape (), dtype int64
# /header/n_prim: shape (), dtype int64
# /header/n_prims_passive: shape (), dtype int64
# /header/n_step: shape (), dtype int32
# /header/ncycle: shape (), dtype int64
# /header/ncycle_out: shape (), dtype int64
# /header/ncycle_out_mesh: shape (), dtype int64
# /header/ng_file: shape (), dtype int32
# /header/nghost: shape (), dtype int64
# /header/nlim: shape (), dtype int64
# /header/num_blocks: shape (), dtype int32
# /header/num_threads: shape (), dtype int64
# /header/nx1: shape (), dtype int64
# /header/nx2: shape (), dtype int64
# /header/nx3: shape (), dtype int64
# /header/on: shape (), dtype int64
# /header/ox1_bc: shape (), dtype |S20
# /header/ox2_bc: shape (), dtype |S20
# /header/ox3_bc: shape (), dtype |S20
# /header/pack_size: shape (), dtype int64
# /header/prim_names: shape (8,), dtype |S20
# /header/r_eh: shape (), dtype float64
# /header/r_in: shape (), dtype float64
# /header/r_out: shape (), dtype int64
# /header/reconstruction: shape (), dtype |S20
# /header/recv_bdry_buf_timeout_sec: shape (), dtype int64
# /header/refine_tol: shape (), dtype float64
# /header/refinement: shape (), dtype |S20
# /header/refinement_in_one_min_nbufs: shape (), dtype int64
# /header/restart_x1max: shape (), dtype int64
# /header/restart_x1min: shape (), dtype int64
# /header/rhor: shape (), dtype float64
# /header/rin: shape (), dtype float64
# /header/rmax: shape (), dtype float64
# /header/spherical: shape (), dtype int64
# /header/start_dt_light: shape (), dtype int64
# /header/start_time: shape (), dtype int64
# /header/startx1: shape (), dtype float64
# /header/startx2: shape (), dtype int64
# /header/startx3: shape (), dtype int64
# /header/sync_utop_seed: shape (), dtype int64
# /header/t: shape (), dtype float64
# /header/tf: shape (), dtype float64
# /header/tilt: shape (), dtype float64
# /header/tlim: shape (), dtype float64
# /header/transform: shape (), dtype |S20
# /header/use_dt_light: shape (), dtype int64
# /header/use_dt_light_phase_speed: shape (), dtype int64
# /header/version: shape (), dtype |S20
# /header/x1max: shape (), dtype float64
# /header/x1min: shape (), dtype float64
# /header/x1rat: shape (), dtype int64
# /header/x2max: shape (), dtype int64
# /header/x2min: shape (), dtype int64
# /header/x2rat: shape (), dtype int64
# /header/x3max: shape (), dtype float64
# /header/x3min: shape (), dtype int64
# /header/x3rat: shape (), dtype int64
# /htht/omega: shape (1581, 48), dtype float32
# /rt/FE_all: shape (1581, 192), dtype float32
# /rt/FE_disk: shape (1581, 192), dtype float32
# /rt/FL_all: shape (1581, 192), dtype float32
# /rt/FL_disk: shape (1581, 192), dtype float32
# /rt/FM_all: shape (1581, 192), dtype float32
# /rt/FM_disk: shape (1581, 192), dtype float32
# /rt/JE0: shape (1581, 192), dtype float32
# /rt/JE1: shape (1581, 192), dtype float32
# /rt/JE2: shape (1581, 192), dtype float32
# /rt/Pg_disk: shape (1581, 192), dtype float32
# /rt/Pg_notdisk: shape (1581, 192), dtype float32
# /rt/Ptot_disk: shape (1581, 192), dtype float32
# /rt/Ptot_notdisk: shape (1581, 192), dtype float32
# /rt/b_disk: shape (1581, 192), dtype float32
# /rt/b_notdisk: shape (1581, 192), dtype float32
# /rt/inv_beta_disk: shape (1581, 192), dtype float32
# /rt/inv_beta_notdisk: shape (1581, 192), dtype float32
# /rt/outEflow: shape (1581, 192), dtype float32
# /rt/outflow: shape (1581, 192), dtype float32
# /rt/rho_disk: shape (1581, 192), dtype float32
# /rt/rho_notdisk: shape (1581, 192), dtype float32
# /rt/u^3_disk: shape (1581, 192), dtype float32
# /rt/u^3_notdisk: shape (1581, 192), dtype float32
# /rt/u^r_disk: shape (1581, 192), dtype float32
# /rt/u^r_notdisk: shape (1581, 192), dtype float32
# /rt/u_3_disk: shape (1581, 192), dtype float32
# /rt/u_3_notdisk: shape (1581, 192), dtype float32
# /rtht/Theta: shape (1581, 192, 96), dtype float32
# /rtht/inv_beta: shape (1581, 192, 96), dtype float32
# /rtht/rho: shape (1581, 192, 96), dtype float32
# /rtht/sigma: shape (1581, 192, 96), dtype float32
# /t/Edot: shape (1581,), dtype float32
# /t/Ldot: shape (1581,), dtype float32
# /t/Mdot: shape (1581,), dtype float32
# /t/Phi_b: shape (1581,), dtype float32
# /t/Phi_b_5: shape (1581,), dtype float32
# /t/Phi_b_lower: shape (1581,), dtype float32
# /t/Phi_b_lower_5: shape (1581,), dtype float32
# /t/Phi_b_upper: shape (1581,), dtype float32
# /t/Phi_b_upper_5: shape (1581,), dtype float32
# /t/is_avg: shape (1581,), dtype float32
# /tht/inv_beta_40: shape (1581, 96), dtype float32
# /tht/sigma_40: shape (1581, 96), dtype float32
#
# 属性:

# %%
r_base = ana['r']
rt_rho_disk = ana['rt/rho_disk'][500:1000,:]
rt_rho_notdisk = ana['rt/rho_notdisk'][500:1000,:]
plt.plot(r_base, np.mean(rt_rho_disk, axis=0), label='disk')
plt.plot(r_base, np.mean(rt_rho_notdisk, axis=0), label='not disk')
plt.xscale('log')
plt.show()

# %%
rt_FM_all = ana['rt/FM_all'][500:1000,:]
rt_FM_disk = ana['rt/FM_disk'][500:1000,:]

plt.plot(r_base, np.mean(rt_FM_all, axis=0), label='all')
plt.plot(r_base, np.mean(rt_FM_disk, axis=0), label='disk')
plt.legend()
plt.xscale('log')
plt.show()

# %%
rt_outflow = ana['rt/outflow'][500:1000,:]
plt.plot(r_base, np.mean(rt_outflow, axis=0))
plt.xscale('log')
plt.show()
