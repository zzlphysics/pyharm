# %%
import sys
import numpy as np
import pyharm

# %%
dump = pyharm.load_dump("/home/zhangzelin/projects/kharma/cluster/20240915_hip_sane_a09375_288-128-128/torus.out0.00000.phdf")

# %%
Pg_max = np.max(dump['Pg'])
print("Gas pressure max: ", np.max(dump['Pg']))
Pb_max = np.max(dump['Pb'])
print("Mag. pressure max: ", np.max(dump['Pb']))
print("beta_min: ", Pg_max/Pb_max)
# Out:
# Gas pressure max:  0.006365557590016163
# Mag. pressure max:  6.365557648989709e-05
# beta_min:  99.99999907355254
