# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def parse_history_file(filename):
    headers = []
    data = []
    
    with open(filename, 'r') as f:
        for line in f:
            if not line.strip():
                continue
                
            # 处理注释行中的列名
            if line.startswith('# ['):
                parts = line.strip('# \n').split()
                for part in parts:
                    if '=' in part:
                        # 提取等号后面的名称，并移除方括号和数字
                        header = part.split('=')[1].strip()
                        # 移除方括号及其中的数字
                        header = header.split('[')[0].strip()
                        headers.append(header)
            
            # 处理数据行
            elif not line.startswith('#'):
                row_data = [float(x) for x in line.split()]
                data.append(row_data)
    
    # 将数据转换为字典格式
    result = {}
    for i, header in enumerate(headers):
        result[header] = [row[i] for row in data]
    
    return result

# %%
file_path0 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a05000_1024-512-1_10-18_min020/torus.hst'
file_path1 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a05000_1024-512-1_10-18_min025/torus.hst'
file_path2 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020/torus.hst'
file_path3 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020_ujitter1/torus.hst'
file_path4 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020_ujitter8/torus.hst'
file_path5 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min025/torus.hst'
file_path6 = '/home/zhangzelin/projects/kharma/output/20241109_hip4_sane_a5000_288-128-128/torus.hst'
file_path7 = '/home/zhangzelin/projects/kharma/output/20241009_hip_sane_a09375_288-128-128_trans/torus.hst'
file_path8 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_00000_192-96-96/torus.hst'

history_data0 = parse_history_file(file_path0)
history_data1 = parse_history_file(file_path1)
history_data2 = parse_history_file(file_path2)
history_data3 = parse_history_file(file_path3)
history_data4 = parse_history_file(file_path4)
history_data5 = parse_history_file(file_path5)
history_data6 = parse_history_file(file_path6)
history_data7 = parse_history_file(file_path7)
history_data8 = parse_history_file(file_path8)
print(history_data0.keys())
# Out:
# dict_keys(['time', 'dt', 'MaxDivB', 'Phi_0', 'Phi_EH', 'Phi_5M', 'FFlags', 'Mass', 'Egas', 'X1_Mom', 'X2_Mom', 'Ang_Mom', 'EHT_Lum_Proxy', 'Mdot', 'Mdot_EH', 'Mdot_5M', 'Edot', 'Edot_EH', 'Edot_5M', 'Ldot', 'Ldot_EH', 'Ldot_5M', 'Mdot_Flux'])

# %%
t0 = history_data0['time']
Phi_EH0 = history_data0['Phi_EH']
Phi_5M0 = history_data0['Phi_5M']
Mass0 = history_data0['Mass']
Mdot0 = history_data0['Mdot']
Mdot_EH0 = history_data0['Mdot_EH']
Mdot_5M0 = history_data0['Mdot_5M']
Mdot_Flux0 = history_data0['Mdot_Flux']

t1 = history_data1['time']
Phi_EH1 = history_data1['Phi_EH']
Phi_5M1 = history_data1['Phi_5M']
Mass1 = history_data1['Mass']
Mdot1 = history_data1['Mdot']
Mdot_EH1 = history_data1['Mdot_EH']
Mdot_5M1 = history_data1['Mdot_5M']
Mdot_Flux1 = history_data1['Mdot_Flux']

t2 = history_data2['time']
Phi_EH2 = history_data2['Phi_EH']
Phi_5M2 = history_data2['Phi_5M']
Mass2 = history_data2['Mass']
Mdot2 = history_data2['Mdot']
Mdot_EH2 = history_data2['Mdot_EH']
Mdot_5M2 = history_data2['Mdot_5M']
Mdot_Flux2 = history_data2['Mdot_Flux']

t3 = history_data3['time']
Phi_EH3 = history_data3['Phi_EH']
Phi_5M3 = history_data3['Phi_5M']
Mass3 = history_data3['Mass']
Mdot3 = history_data3['Mdot']
Mdot_EH3 = history_data3['Mdot_EH']
Mdot_5M3 = history_data3['Mdot_5M']
Mdot_Flux3 = history_data3['Mdot_Flux']

t4 = history_data4['time']
Phi_EH4 = history_data4['Phi_EH']
Phi_5M4 = history_data4['Phi_5M']
Mass4 = history_data4['Mass']
Mdot4 = history_data4['Mdot']
Mdot_EH4 = history_data4['Mdot_EH']
Mdot_5M4 = history_data4['Mdot_5M']
Mdot_Flux4 = history_data4['Mdot_Flux']

t5 = history_data5['time']
Phi_EH5 = history_data5['Phi_EH']
Phi_5M5 = history_data5['Phi_5M']
Mass5 = history_data5['Mass']
Mdot5 = history_data5['Mdot']
Mdot_EH5 = history_data5['Mdot_EH']
Mdot_5M5 = history_data5['Mdot_5M']
Mdot_Flux5 = history_data5['Mdot_Flux']

t6 = history_data6['time']
Phi_EH6 = history_data6['Phi_EH']
Phi_5M6 = history_data6['Phi_5M']
Mass6 = history_data6['Mass']
Mdot6 = history_data6['Mdot']
Mdot_EH6 = history_data6['Mdot_EH']
Mdot_5M6 = history_data6['Mdot_5M']
Mdot_Flux6 = history_data6['Mdot_Flux']

t7 = history_data7['time']
Phi_EH7 = history_data7['Phi_EH']
Phi_5M7 = history_data7['Phi_5M']
Mass7 = history_data7['Mass']
Mdot7 = history_data7['Mdot']
Mdot_EH7 = history_data7['Mdot_EH']
Mdot_5M7 = history_data7['Mdot_5M']
Mdot_Flux7 = history_data7['Mdot_Flux']

# %%
print(np.array(Mdot_EH5).shape)
print(Mdot_EH7[1000], Mdot_5M7[1000],Phi_EH7[1000], Phi_5M7[1000])
# Out:
# (112295,)
# 0.0 2.48428e-05 3.64242e-07 0.0

# %%
fig1, ax1 = plt.subplots(2,1,figsize=(10, 6))

ax1[0].plot(t0, Phi_EH0, label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t1, Phi_EH1, label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax1[0].plot(t2, Phi_EH2, label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t3, Phi_EH3, label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t4, Phi_EH4, label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t5, Phi_EH5, label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t6, Phi_EH6, label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax1[0].plot(t7, Phi_EH7, label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax1[0].legend()

ax1[1].plot(t0, Phi_5M0, label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t1, Phi_5M1, label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax1[1].plot(t2, Phi_5M2, label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t3, Phi_5M3, label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t4, Phi_5M4, label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t5, Phi_5M5, label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t6, Phi_5M6, label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax1[1].plot(t7, Phi_5M7, label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax1[1].legend()

# ax1[0].set_yscale('log')
# ax1[0].set_ylim(1e-1,1e1)
# ax1[1].set_yscale('log')
# ax1[1].set_ylim(1e-1,1e1)
ax1[0].set_xlabel('time')
ax1[0].set_ylabel('Phi_EH')
ax1[1].set_xlabel('time')
ax1[1].set_ylabel('Phi_5M')
plt.show()

# %%
Mdot_EH_avg_a05_min020 = np.average(Mdot_EH0[80000:100000])
Mdot_EH_avg_a05_min025 = np.average(Mdot_EH1[80000:100000])
Mdot_EH_avg_a09375_min020 = np.average(Mdot_EH2[80000:100000])
Mdot_EH_avg_a09375_ujitter1 = np.average(Mdot_EH3[80000:100000])
Mdot_EH_avg_a09375_ujitter8 = np.average(Mdot_EH4[80000:100000])
Mdot_EH_avg_a09375_min025 = np.average(Mdot_EH5[80000:100000])

print("Mdot_EH_avg_a05_min020", Mdot_EH_avg_a05_min020)
print("Mdot_EH_avg_a05_min025", Mdot_EH_avg_a05_min025)
print("Mdot_EH_avg_a09375_min020", Mdot_EH_avg_a09375_min020)
print("Mdot_EH_avg_a09375_ujitter1", Mdot_EH_avg_a09375_ujitter1)
print("Mdot_EH_avg_a09375_ujitter8", Mdot_EH_avg_a09375_ujitter8)
print("Mdot_EH_avg_a09375_min025", Mdot_EH_avg_a09375_min025)
# Out:
# Mdot_EH_avg_a05_min020 0.016097979174
# Mdot_EH_avg_a05_min025 0.15961914255
# Mdot_EH_avg_a09375_min020 0.0140653631615
# Mdot_EH_avg_a09375_ujitter1 0.020483757819739035
# Mdot_EH_avg_a09375_ujitter8 0.00843214652049376
# Mdot_EH_avg_a09375_min025 0.011940466540500001

# %%
Phi_EH_avg_a05_min020 = np.average(Phi_EH0[80000:100000])
Phi_EH_avg_a05_min025 = np.average(Phi_EH1[80000:100000])
Phi_EH_avg_a09375_min020 = np.average(Phi_EH2[80000:100000])
Phi_EH_avg_a09375_ujitter1 = np.average(Phi_EH3[80000:100000])
Phi_EH_avg_a09375_ujitter8 = np.average(Phi_EH4[80000:100000])
Phi_EH_avg_a09375_min025 = np.average(Phi_EH5[80000:100000])

print("Phi_EH_avg_a05_min020", Phi_EH_avg_a05_min020)
print("Phi_EH_avg_a05_min025", Phi_EH_avg_a05_min025)
print("Phi_EH_avg_a09375_min020", Phi_EH_avg_a09375_min020)
print("Phi_EH_avg_a09375_ujitter1", Phi_EH_avg_a09375_ujitter1)
print("Phi_EH_avg_a09375_ujitter8", Phi_EH_avg_a09375_ujitter8)
print("Phi_EH_avg_a09375_min025", Phi_EH_avg_a09375_min025)
# Out:
# Phi_EH_avg_a05_min020 0.9814705926999999
# Phi_EH_avg_a05_min025 0.9736833685499999
# Phi_EH_avg_a09375_min020 1.0425489245000001
# Phi_EH_avg_a09375_ujitter1 1.0572702201528998
# Phi_EH_avg_a09375_ujitter8 1.034932632476301
# Phi_EH_avg_a09375_min025 0.9565909313500001

# %%
print(1.36/np.sqrt(0.067))
print(1.0425/np.sqrt(0.014))
# Out:
# 5.25413838314654
# 8.810733105544784

# %%
fig2, ax2 = plt.subplots(4,1,figsize=(10, 12))
dp = 500
ax2[0].plot(t0[::dp], Phi_EH0[::dp]/np.sqrt(Mdot_EH0[::dp]), label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t1[::dp], Phi_EH1[::dp]/np.sqrt(Mdot_EH1[::dp]), label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax2[0].plot(t2[::dp], Phi_EH2[::dp]/np.sqrt(Mdot_EH2[::dp]), label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t3[::dp], Phi_EH3[::dp]/np.sqrt(Mdot_EH3[::dp]), label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t4[::dp], Phi_EH4[::dp]/np.sqrt(Mdot_EH4[::dp]), label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t5[::dp], Phi_EH5[::dp]/np.sqrt(Mdot_EH5[::dp]), label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t6[::dp], Phi_EH6[::dp]/np.sqrt(Mdot_EH6[::dp]), label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax2[0].plot(t7[::dp], Phi_EH7[::dp]/np.sqrt(Mdot_EH7[::dp]), label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax2[0].legend()
ax2[0].set_xlabel('time')
ax2[0].set_ylabel('Phi_EH/sqrt(Mdot_EH)')

ax2[1].plot(t0[::dp], Phi_5M0[::dp]/np.sqrt(Mdot_5M0[::dp]), label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t1[::dp], Phi_5M1[::dp]/np.sqrt(Mdot_5M1[::dp]), label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax2[1].plot(t2[::dp], Phi_5M2[::dp]/np.sqrt(Mdot_5M2[::dp]), label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t3[::dp], Phi_5M3[::dp]/np.sqrt(Mdot_5M3[::dp]), label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t4[::dp], Phi_5M4[::dp]/np.sqrt(Mdot_5M4[::dp]), label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t5[::dp], Phi_5M5[::dp]/np.sqrt(Mdot_5M5[::dp]), label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t6[::dp], Phi_5M6[::dp]/np.sqrt(Mdot_5M6[::dp]), label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax2[1].plot(t7[::dp], Phi_5M7[::dp]/np.sqrt(Mdot_5M7[::dp]), label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax2[1].legend()
ax2[1].set_xlabel('time')
ax2[1].set_ylabel('Phi_5M/sqrt(Mdot_5M)')

ax2[2].plot(t0[::dp], Phi_EH0[::dp]/np.sqrt(np.average(Mdot_EH0[50000:])), label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t1[::dp], Phi_EH1[::dp]/np.sqrt(np.average(Mdot_EH1[50000:])), label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax2[2].plot(t2[::dp], Phi_EH2[::dp]/np.sqrt(np.average(Mdot_EH2[50000:])), label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t3[::dp], Phi_EH3[::dp]/np.sqrt(np.average(Mdot_EH3[50000:])), label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t4[::dp], Phi_EH4[::dp]/np.sqrt(np.average(Mdot_EH4[50000:])), label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t5[::dp], Phi_EH5[::dp]/np.sqrt(np.average(Mdot_EH5[50000:])), label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t6[::dp], Phi_EH6[::dp]/np.sqrt(np.average(Mdot_EH6[30000:])), label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax2[2].plot(t7[::dp], Phi_EH7[::dp]/np.sqrt(np.average(Mdot_EH7[30000:])), label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax2[2].legend()
ax2[2].set_xlabel('time')
ax2[2].set_ylabel('Phi_EH/sqrt(<Mdot_EH>)')

ax2[3].plot(t0[::dp], Phi_5M0[::dp]/np.sqrt(np.average(Mdot_5M0[50000:])), label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t1[::dp], Phi_5M1[::dp]/np.sqrt(np.average(Mdot_5M1[50000:])), label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax2[3].plot(t2[::dp], Phi_5M2[::dp]/np.sqrt(np.average(Mdot_5M2[50000:])), label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t3[::dp], Phi_5M3[::dp]/np.sqrt(np.average(Mdot_5M3[50000:])), label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t4[::dp], Phi_5M4[::dp]/np.sqrt(np.average(Mdot_5M4[50000:])), label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t5[::dp], Phi_5M5[::dp]/np.sqrt(np.average(Mdot_5M5[50000:])), label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t6[::dp], Phi_5M6[::dp]/np.sqrt(np.average(Mdot_5M6[30000:])), label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax2[3].plot(t7[::dp], Phi_5M7[::dp]/np.sqrt(np.average(Mdot_5M7[30000:])), label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax2[3].legend()
ax2[3].set_xlabel('time')
ax2[3].set_ylabel('Phi_5M/sqrt(<Mdot_5M>)')

ax2[0].set_ylim(0,15)
ax2[1].set_ylim(0,15)
ax2[2].set_ylim(0,15)
ax2[3].set_ylim(0,15)

# ax2[0].set_yscale('log')
# ax2[0].set_ylim(1e-1,1e1)
# ax2[1].set_yscale('log')
# ax2[1].set_ylim(1e-1,1e1)
# ax2[2].set_yscale('log')
# ax2[2].set_ylim(1e-1,1e1)
# ax2[3].set_yscale('log')
# ax2[3].set_ylim(1e-1,1e1)
plt.show()

# %%
fig3, ax3 = plt.subplots(figsize=(10, 6))

ax3.plot(t0, Mass0, label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax3.plot(t1, Mass1, label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax3.plot(t2, Mass2, label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax3.plot(t3, Mass3, label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
ax3.plot(t4, Mass4, label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
ax3.plot(t5, Mass5, label='a0.9375_min025', alpha=1.0, linewidth=1.0)
ax3.plot(t6, Mass6, label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax3.plot(t7, Mass7, label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax3.set_xlabel('time')
ax3.set_ylabel('Mass')
ax3.legend()
plt.show()

# %%
fig4, ax4 = plt.subplots(figsize=(10, 6))

ax4.plot(t0, np.abs(Mdot0), label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax4.plot(t1, np.abs(Mdot1), label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax4.plot(t2, np.abs(Mdot2), label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax4.plot(t3, np.abs(Mdot3), label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
ax4.plot(t4, np.abs(Mdot4), label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
ax4.plot(t5, np.abs(Mdot5), label='a0.9375_min025', alpha=1.0, linewidth=1.0)

ax4.legend()
plt.show()

# %%
fig5, ax5 = plt.subplots(3,1,figsize=(10, 12))

dp = 500

ax5[0].plot(t0[::dp], Mdot_EH0[::dp], label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax5[0].plot(t1[::dp], Mdot_EH1[::dp], label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax5[0].plot(t2[::dp], Mdot_EH2[::dp], label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax5[0].plot(t3[::dp], Mdot_EH3[::dp], label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
ax5[0].plot(t4[::dp], Mdot_EH4[::dp], label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
ax5[0].plot(t5[::dp], Mdot_EH5[::dp], label='a0.9375_min025', alpha=1.0, linewidth=1.0)
ax5[0].plot(t6[::dp], Mdot_EH6[::dp], label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
ax5[0].plot(t7[::dp], Mdot_EH7[::dp], label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax5[0].set_xlabel('time')
ax5[0].set_ylabel('Mdot_EH')
ax5[0].legend()

# ax5[1].plot(t0[::dp], Mdot_5M0[::dp], label='a0.5_min020', alpha=1.0, linewidth=1.0)
# ax5[1].plot(t1[::dp], Mdot_5M1[::dp], label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax5[1].plot(t2[::dp], Mdot_5M2[::dp], label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax5[1].plot(t3[::dp], Mdot_5M3[::dp], label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
ax5[1].plot(t4[::dp], Mdot_5M4[::dp], label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
# ax5[1].plot(t5[::dp], Mdot_5M5[::dp], label='a0.9375_min025', alpha=1.0, linewidth=1.0)
# ax5[1].plot(t6[::dp], Mdot_5M6[::dp], label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
# ax5[1].plot(t7[::dp], Mdot_5M7[::dp], label='a0.9375_min020_3d', alpha=1.0, linewidth=1.0)
ax5[1].set_xlabel('time')
ax5[1].set_ylabel('Mdot_5M')
ax5[1].legend()

ax5[2].plot(t0[::dp], Mdot_EH0[::dp], label='a0.5_min020', alpha=1.0, linewidth=1.0, linestyle='--')
ax5[2].plot(t0[::dp], Mdot_5M0[::dp], label='a0.5_min020', alpha=1.0, linewidth=1.0, linestyle='-')
ax5[2].plot(t2[::dp], Mdot_EH2[::dp], label='a0.9375_min020', alpha=1.0, linewidth=1.0, linestyle='--')
ax5[2].plot(t2[::dp], Mdot_5M2[::dp], label='a0.9375_min020', alpha=1.0, linewidth=1.0, linestyle='-')

ax5[0].set_yscale('log')
ax5[0].set_ylim(1e-3,1e1)
ax5[1].set_yscale('log')
ax5[1].set_ylim(1e-3,1e1)
ax5[2].set_yscale('log')
ax5[2].set_ylim(1e-3,1e1)


plt.show()

# %%
fig6, ax6 = plt.subplots(figsize=(10, 6))

ax6.plot(t0, Mdot_Flux0, label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax6.plot(t1, Mdot_Flux1, label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax6.plot(t2, Mdot_Flux2, label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax6.plot(t3, Mdot_Flux3, label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
ax6.plot(t4, Mdot_Flux4, label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
ax6.plot(t5, Mdot_Flux5, label='a0.9375_min025', alpha=1.0, linewidth=1.0)

ax4.legend()
plt.show()

# %%
import pyharm.ana_results as an
import matplotlib.pyplot as plt
import numpy as np

# %%
ana_file_path0 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a05000_1024-512-1_10-18_min020/eht_out.h5'
ana_file_path1 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a05000_1024-512-1_10-18_min025/eht_out.h5'
ana_file_path2 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020/eht_out.h5'
ana_file_path3 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020_ujitter1/eht_out.h5'
ana_file_path4 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min020_ujitter8/eht_out.h5'
ana_file_path5 = '/home/zhangzelin/projects/kharma/output/20241121_hip_sane_a09375_1024-512-1_10-18_min025/eht_out.h5'
ana_file_path6 = '/home/zhangzelin/projects/kharma/output/20241109_hip4_sane_a5000_288-128-128/eht_out.h5'
ana_file_path7 = '/home/zhangzelin/projects/kharma/output/20241009_hip_sane_a09375_288-128-128_trans/eht_out.h5'
ana_file_path8 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_00000_192-96-96/eht_out.h5'

ana0 = an.load_results(ana_file_path0)
ana1 = an.load_results(ana_file_path1)
ana2 = an.load_results(ana_file_path2)
ana3 = an.load_results(ana_file_path3)
ana4 = an.load_results(ana_file_path4)
ana5 = an.load_results(ana_file_path5)
ana6 = an.load_results(ana_file_path6)
ana7 = an.load_results(ana_file_path7)
ana8 = an.load_results(ana_file_path8)

# %%
mdot0 = ana0.get_result('t', 'mdot')
mdot1 = ana1.get_result('t', 'mdot')
mdot2 = ana2.get_result('t', 'mdot')
mdot3 = ana3.get_result('t', 'mdot')
mdot4 = ana4.get_result('t', 'mdot')
mdot5 = ana5.get_result('t', 'mdot')
mdot6 = ana6.get_result('t', 'mdot')
mdot7 = ana7.get_result('t', 'mdot')
mdot8 = ana8.get_result('t', 'mdot')

Phi_b0 = ana0.get_result('t', 'Phi_b')
Phi_b1 = ana1.get_result('t', 'Phi_b')
Phi_b2 = ana2.get_result('t', 'Phi_b')
Phi_b3 = ana3.get_result('t', 'Phi_b')
Phi_b4 = ana4.get_result('t', 'Phi_b')
Phi_b5 = ana5.get_result('t', 'Phi_b')
Phi_b6 = ana6.get_result('t', 'Phi_b')
Phi_b7 = ana7.get_result('t', 'Phi_b')
Phi_b8 = ana8.get_result('t', 'Phi_b')

phi_b0 = ana0.get_result('t', 'phi_b')
phi_b1 = ana1.get_result('t', 'phi_b')
phi_b2 = ana2.get_result('t', 'phi_b')
phi_b3 = ana3.get_result('t', 'phi_b')
phi_b4 = ana4.get_result('t', 'phi_b')
phi_b5 = ana5.get_result('t', 'phi_b')
phi_b6 = ana6.get_result('t', 'phi_b')
phi_b7 = ana7.get_result('t', 'phi_b')
phi_b8 = ana8.get_result('t', 'phi_b')

# %%
fig7, ax7 = plt.subplots(figsize=(10, 6))

ax7.plot(mdot0[0], mdot0[1], label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax7.plot(mdot1[0], mdot1[1], label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax7.plot(mdot2[0], mdot2[1], label='a0.9375_min020', alpha=1.0, linewidth=1.0)
# ax7.plot(mdot3[0], mdot3[1], label='a0.9375_ujitter1', alpha=1.0, linewidth=1.0)
# ax7.plot(mdot4[0], mdot4[1], label='a0.9375_ujitter8', alpha=1.0, linewidth=1.0)
ax7.plot(mdot5[0], mdot5[1], label='a0.9375_min025', alpha=1.0, linewidth=1.0)
ax7.plot(mdot6[0], mdot6[1], label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
ax7.legend()
ax7.set_yscale('log')
ax7.set_ylim(1e-3,1e1)
plt.show()

# %%
fig8, ax8 = plt.subplots(figsize=(10, 6))

ax8.plot(mdot0[0], Phi_b0[1], label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax8.plot(mdot1[0], Phi_b1[1], label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax8.plot(mdot2[0], Phi_b2[1], label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax8.plot(mdot5[0], Phi_b5[1], label='a0.9375_min025', alpha=1.0, linewidth=1.0)
ax8.plot(mdot6[0], Phi_b6[1], label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
ax8.legend()

plt.show()

# %%
fig9, ax9 = plt.subplots(figsize=(10, 6))

ax9.plot(mdot0[0], phi_b0[1], label='a0.5_min020', alpha=1.0, linewidth=1.0)
ax9.plot(mdot1[0], phi_b1[1], label='a0.5_min025', alpha=1.0, linewidth=1.0)
ax9.plot(mdot2[0], phi_b2[1], label='a0.9375_min020', alpha=1.0, linewidth=1.0)
ax9.plot(mdot5[0], phi_b5[1], label='a0.9375_min025', alpha=1.0, linewidth=1.0)
ax9.plot(mdot6[0], phi_b6[1], label='a0.5_min020_3d', alpha=1.0, linewidth=1.0)
ax9.legend()

plt.show()

# %%
file_path1 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_09375_192-96-96/torus.hst'
file_path2 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_05000_192-96-96/torus.hst'
file_path3 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_00000_192-96-96/torus.hst'
file_path4 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_-05000_192-96-96/torus.hst'
file_path5 = '/home/zhangzelin/projects/kharma/output/20241018_hip_mad_-09375_192-96-96/torus.hst'
file_path6 = '/home/zhangzelin/projects/kharma/output/20241029_hip_mad_09375_192-96-96/torus.hst'
history_data1 = parse_history_file(file_path1)
history_data2 = parse_history_file(file_path2)
history_data3 = parse_history_file(file_path3)
history_data4 = parse_history_file(file_path4)
history_data5 = parse_history_file(file_path5)
history_data6 = parse_history_file(file_path6)
print(history_data6.keys())
# Out:
# dict_keys(['time', 'dt', 'FOFCFlags', 'Phi_0', 'Phi_EH', 'Phi_5M', 'FFlags', 'Mass', 'Egas', 'X1_Mom', 'X2_Mom', 'Ang_Mom', 'EHT_Lum_Proxy', 'Mdot', 'Mdot_EH', 'Mdot_5M', 'Edot', 'Edot_EH', 'Edot_5M', 'Ldot', 'Ldot_EH', 'Ldot_5M', 'Mdot_Flux'])

# %%
t1 = history_data1['time']
Phi_EH1 = history_data1['Phi_EH']
t2 = history_data2['time']
Phi_EH2 = history_data2['Phi_EH']
t3 = history_data3['time']
Phi_EH3 = history_data3['Phi_EH']
t4 = history_data4['time']
Phi_EH4 = history_data4['Phi_EH']
t5 = history_data5['time']
Phi_EH5 = history_data5['Phi_EH']
t6 = history_data6['time']
Phi_EH6 = history_data6['Phi_EH']

plt.plot(t1, Phi_EH1, label='0.9375')
plt.plot(t2, Phi_EH2, label='0.5')
plt.plot(t3, Phi_EH3, label='0')
plt.plot(t4, Phi_EH4, label='-0.5')
plt.plot(t5, Phi_EH5, label='-0.9375')
plt.plot(t6, Phi_EH6, label='0.9375')
plt.legend()
plt.show()

# %%
t6 = history_data6['time']
mdot_eh_6 = -np.array(history_data6['Mdot_EH'])
plt.plot(t6, mdot_eh_6, label='mdot_eh')
plt.legend()
plt.show()

# %%
Phi_EH_6 = np.array(history_data6['Phi_EH'])
plt.plot(t6, Phi_EH_6, label='Phi_EH')
plt.legend()
plt.show()

# %%
phi = Phi_EH_6 * mdot_eh_6**-0.5
plt.plot(t6[14000:], phi[14000:], label='phi')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_482804/972019923.py:1: RuntimeWarning: divide by zero encountered in power
#   phi = Phi_EH_6 * mdot_eh_6**-0.5
# /tmp/ipykernel_482804/972019923.py:1: RuntimeWarning: invalid value encountered in power
#   phi = Phi_EH_6 * mdot_eh_6**-0.5
# /tmp/ipykernel_482804/972019923.py:1: RuntimeWarning: invalid value encountered in multiply
#   phi = Phi_EH_6 * mdot_eh_6**-0.5

# %%
import pyharm.ana_results as an
import matplotlib.pyplot as plt
import numpy as np

# %%
ana_file1 = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_09375_192-96-96/eht_out.h5"
ana_file2 = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_05000_192-96-96/eht_out.h5"
ana_file3 = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_00000_192-96-96/eht_out.h5"
ana_file4 = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_-05000_192-96-96/eht_out.h5"
ana_file5 = "/home/zhangzelin/projects/kharma/output/20241018_hip_mad_-09375_192-96-96/eht_out.h5"
ana_file6 = "/home/zhangzelin/projects/kharma/output/20241029_hip_mad_09375_192-96-96/eht_out.h5"

ana1 = an.load_results(ana_file1)
ana2 = an.load_results(ana_file2)
ana3 = an.load_results(ana_file3)
ana4 = an.load_results(ana_file4)
ana5 = an.load_results(ana_file5)
ana6 = an.load_results(ana_file6)

# %%
mdot1 = ana1.get_result('t', 'mdot')
mdot2 = ana2.get_result('t', 'mdot')
mdot3 = ana3.get_result('t', 'mdot')
mdot4 = ana4.get_result('t', 'mdot')
mdot5 = ana5.get_result('t', 'mdot')
mdot6 = ana6.get_result('t', 'mdot')

# %%
plt.yscale('log')


plt.plot(mdot1[0][0:900], mdot1[1][0:900], label='0.9375', alpha=0.8)
plt.plot(mdot2[0], mdot2[1], label='0.5', alpha=0.8)
plt.plot(mdot3[0], mdot3[1], label='0', alpha=0.8)
plt.plot(mdot4[0], mdot4[1], label='-0.5', alpha=0.8)
plt.plot(mdot5[0], mdot5[1], label='-0.9375', alpha=0.8)
plt.plot(mdot6[0], mdot6[1], label='0.9375_new', alpha=0.8)
plt.legend()
plt.show()

# %%
phi_b1 = ana1.get_result('t', 'phi_b')
phi_b2 = ana2.get_result('t', 'phi_b')
phi_b3 = ana3.get_result('t', 'phi_b')
phi_b4 = ana4.get_result('t', 'phi_b')
phi_b5 = ana5.get_result('t', 'phi_b')
phi_b6 = ana6.get_result('t', 'phi_b')

# %%
# plt.yscale('log')
plt.plot(phi_b1[0][0:900], phi_b1[1][0:900], label='0.9375', alpha=0.8)
plt.plot(phi_b2[0], phi_b2[1], label='0.5', alpha=0.8)
plt.plot(phi_b3[0], phi_b3[1], label='0', alpha=0.8)
plt.plot(phi_b4[0], phi_b4[1], label='-0.5', alpha=0.8)
plt.plot(phi_b5[0], phi_b5[1], label='-0.9375', alpha=0.8)
plt.plot(phi_b6[0], phi_b6[1], label='0.9375_new', alpha=0.8)
plt.legend()
plt.show()

# %%
import pyharm.ana_results as an
import matplotlib.pyplot as plt
import numpy as np

# %%
ana_file1 = "/home/zhangzelin/projects/kharma/output/20241105_hip_kz_sane_05000_eta+00_512-384-1/eht_out.h5"
ana_file2 = "/home/zhangzelin/projects/kharma/output/20241105_hip_kz_sane_05000_eta+05_512-384-1/eht_out.h5"
ana_file3 = "/home/zhangzelin/projects/kharma/output/20241105_hip_kz_sane_05000_eta-05_512-384-1/eht_out.h5"

ana1 = an.load_results(ana_file1)
ana2 = an.load_results(ana_file2)
ana3 = an.load_results(ana_file3)

# %%
mdot1 = ana1.get_result('t', 'mdot')
mdot2 = ana2.get_result('t', 'mdot')
mdot3 = ana3.get_result('t', 'mdot')

plt.plot(mdot1[0], mdot1[1], label='eta+00', alpha=0.8)
plt.plot(mdot2[0], mdot2[1], label='eta+05', alpha=0.8)
plt.plot(mdot3[0], mdot3[1], label='eta-05', alpha=0.8)
plt.legend()
plt.show()

# %%
phi_b1 = ana1.get_result('t', 'phi_b')
phi_b2 = ana2.get_result('t', 'phi_b')
phi_b3 = ana3.get_result('t', 'phi_b')

plt.plot(phi_b1[0], phi_b1[1], label='eta+00', alpha=0.8)
plt.plot(phi_b2[0], phi_b2[1], label='eta+05', alpha=0.8)
plt.plot(phi_b3[0], phi_b3[1], label='eta-05', alpha=0.8)
plt.legend()
plt.show()

# %%
eff1 = ana1.get_result('t', 'eff')
eff2 = ana2.get_result('t', 'eff')
eff3 = ana3.get_result('t', 'eff')

plt.plot(eff1[0], eff1[1], label='eta+00', alpha=0.8)
plt.plot(eff2[0], eff2[1], label='eta+05', alpha=0.8)
plt.plot(eff3[0], eff3[1], label='eta-05', alpha=0.8)
